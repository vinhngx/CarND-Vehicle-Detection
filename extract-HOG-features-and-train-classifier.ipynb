# %%
import glob, os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import cv2
import glob
import time
from sklearn.svm import LinearSVC, SVC
from sklearn.preprocessing import StandardScaler
from skimage.feature import hog
# NOTE: the next import is only valid for scikit-learn version <= 0.17
# for scikit-learn >= 0.18 use:
# from sklearn.model_selection import train_test_split
import sklearn
print(sklearn.__version__)
from sklearn.cross_validation import train_test_split  
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import accuracy_score
# Out:
# 0.19.1

# %%
# read list of vehicles file
cars = []
for directory in glob.glob("data/vehicles/*"):
    cars.extend(glob.glob(directory+"/*"))
len(cars)
# Out:
# 8792

# %%
notcars = []
for directory in glob.glob("data/non-vehicles/*"):
    notcars.extend(glob.glob(directory+"/*"))
len(notcars)
# Out:
# 8968

# %%
from random import shuffle

shuffle(cars)
shuffle(notcars)

plt.figure(figsize=(20,20))    
for i in range(100):
    plt.subplot(10,10,i+1)
    plt.imshow(mpimg.imread(cars[i]))
    plt.axis('off')
plt.suptitle('Cars')
plt.savefig('examples/cars_examples.png')

plt.figure(figsize=(20,20))    
for i in range(100):
    plt.subplot(10,10,i+1)
    plt.imshow(mpimg.imread(notcars[i]))
    plt.axis('off')
plt.suptitle('Noncars')    
plt.savefig('examples/noncars_examples.png')
plt.show()

# %% [markdown]
# # Extracting HOG features

# %%
# Define a function to return HOG features and visualization
def get_hog_features(img, orient, pix_per_cell, cell_per_block, 
                        vis=False, feature_vec=True):
    # Call with two outputs if vis==True
    if vis == True:
        features, hog_image = hog(img, orientations=orient, pixels_per_cell=(pix_per_cell, pix_per_cell),
                                  cells_per_block=(cell_per_block, cell_per_block), block_norm= 'L2-Hys',
                                  transform_sqrt=True, 
                                  visualise=vis, feature_vector=feature_vec)
        return features, hog_image
    # Otherwise call with one output
    else:      
        features = hog(img, orientations=orient, pixels_per_cell=(pix_per_cell, pix_per_cell),
                       cells_per_block=(cell_per_block, cell_per_block), block_norm= 'L2-Hys',
                       transform_sqrt=True, 
                       visualise=vis, feature_vector=feature_vec)
        return features

# %%
# test HOG visualization
img = mpimg.imread(cars[0])
orient = 9
pix_per_cell = 8
cell_per_block = 2
features, hog_image = get_hog_features(img[:,:,0], orient, pix_per_cell, cell_per_block, 
                        vis=True, feature_vec=True)

plt.figure(figsize=(20,20));
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(hog_image)

# %%
np.mean(features)
# Out:
# 1.1908447184174293

# %%
features.shape
# Out:
# (1764,)

# %%
# Define a function to extract features from a list of images
# Have this function call bin_spatial() and color_hist()
def extract_features(imgs, cspace='RGB', orient=9, 
                        pix_per_cell=8, cell_per_block=2, hog_channel='ALL'):
    # Create a list to append feature vectors to
    features = []
    # Iterate through the list of images
    for file in imgs:
        # Read in each one by one
        image = mpimg.imread(file)
        # apply color conversion if other than 'RGB'
        if cspace != 'RGB':
            if cspace == 'HSV':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
            elif cspace == 'LUV':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2LUV)
            elif cspace == 'HLS':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2HLS)
            elif cspace == 'YUV':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2YUV)
            elif cspace == 'YCrCb':
                feature_image = cv2.cvtColor(image, cv2.COLOR_RGB2YCrCb)
        else: feature_image = np.copy(image)      

        # Call get_hog_features() with vis=False, feature_vec=True
        if hog_channel == 'ALL':
            hog_features = []
            for channel in range(feature_image.shape[2]):
                hog_features.append(get_hog_features(feature_image[:,:,channel], 
                                    orient, pix_per_cell, cell_per_block, 
                                    vis=False, feature_vec=True))
            hog_features = np.ravel(hog_features)        
        else:
            hog_features = get_hog_features(feature_image[:,:,hog_channel], orient, 
                        pix_per_cell, cell_per_block, vis=False, feature_vec=True)
        # Append the new feature vector to the features list
        features.append(hog_features)
    # Return list of feature vectors
    return features

# %%
# Reduce the sample size because HOG features are slow to compute
# The quiz evaluator times out after 13s of CPU time
#sample_size = 500 #set sample_size = -1 to include all images
#cars = cars[0:sample_size]
#notcars = notcars[0:sample_size]

# %%
len(cars)
# Out:
# 8792

# %%
### TODO: Tweak these parameters and see how the results change.
colorspace = 'RGB' # Can be RGB, HSV, LUV, HLS, YUV, YCrCb
orient = 9
pix_per_cell = 8
cell_per_block = 2
hog_channel = 'ALL' # Can be 0, 1, 2, or "ALL"

t=time.time()
car_features = extract_features(cars, cspace=colorspace, orient=orient, 
                        pix_per_cell=pix_per_cell, cell_per_block=cell_per_block, 
                        hog_channel=hog_channel)
notcar_features = extract_features(notcars, cspace=colorspace, orient=orient, 
                        pix_per_cell=pix_per_cell, cell_per_block=cell_per_block, 
                        hog_channel=hog_channel)
t2 = time.time()
print(round(t2-t, 2), 'Seconds to extract HOG features...')
# Out:
# 86.16 Seconds to extract HOG features...

# %%
norm_car_features = [np.linalg.norm(x) for x in car_features ]
norm_notcar_features = [np.linalg.norm(x) for x in notcar_features ]

print(np.max(norm_car_features))
print(np.max(norm_notcar_features))

plt.hist(norm_car_features, 50,  alpha=0.5, label='norm_car_features')
plt.hist(norm_notcar_features, 50,  alpha=0.5, label='norm_notcar_features')
plt.legend(loc='upper right')
plt.show()
# Out:
# 23266.549046534587
# 10681.388960980665

# %%
print(np.mean(norm_car_features))
print(np.mean(norm_notcar_features))
# Out:
# 267.00434479626205
# 1052.2790891527313

# %%
import pickle
with open('features.pickle', 'wb') as handle:
    pickle.dump({'car_features':car_features, 'notcar_features':notcar_features}, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Training classifiers

# %%
# Create an array stack of feature vectors
X = np.vstack((car_features, notcar_features)).astype(np.float64)

# Define the labels vector
y = np.hstack((np.ones(len(car_features)), np.zeros(len(notcar_features))))

# Split up data into randomized training and test sets
rand_state = np.random.randint(0, 100)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=rand_state)
    
# Fit a per-column scaler
X_scaler = StandardScaler(copy=True, with_mean=True, with_std=True).fit(X_train)
# Apply the scaler to X
X_train = X_scaler.transform(X_train)
X_test = X_scaler.transform(X_test)

print('Using:',orient,'orientations',pix_per_cell,
    'pixels per cell and', cell_per_block,'cells per block')
print('Feature vector length:', len(X_train[0]))
# Out:
# Using: 9 orientations 8 pixels per cell and 2 cells per block
# Feature vector length: 5292

# %%
X_train.shape
# Out:
# (14208, 5292)

# %%
np.linalg.norm(X_train[:,100])
# Out:
# 119.19731540601019

# %%
X_train[0].shape
# Out:
# (5292,)

# %% [markdown]
# ## Linear SVM

# %%
# Use a linear SVC 
svc = LinearSVC()
# Check the training time for the SVC
t=time.time()
svc.fit(X_train, y_train)
t2 = time.time()
print(round(t2-t, 2), 'Seconds to train SVC...')
# Check the score of the SVC
print('Test Accuracy of SVC = ', round(svc.score(X_test, y_test), 4))
# Check the prediction time for a single sample
t=time.time()
n_predict = 10
print('My SVC predicts: ', svc.predict(X_test[0:n_predict]))
print('For these',n_predict, 'labels: ', y_test[0:n_predict])
t2 = time.time()
print(round(t2-t, 5), 'Seconds to predict', n_predict,'labels with SVC')
# Out:
# 38.79 Seconds to train SVC...
# Test Accuracy of SVC =  0.9257
# My SVC predicts:  [0. 1. 0. 1. 1. 0. 0. 0. 0. 0.]
# For these 10 labels:  [0. 1. 0. 1. 1. 0. 1. 0. 0. 0.]
# 0.00696 Seconds to predict 10 labels with SVC

# %%
svc = SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
    decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
    max_iter=-1, probability=False, random_state=None, shrinking=True,
    tol=0.001, verbose=False)
# Check the training time for the SVC
t=time.time()
svc.fit(X_train, y_train)
t2 = time.time()
print(round(t2-t, 2), 'Seconds to train SVC...')
# Check the score of the SVC
print('Test Accuracy of SVC = ', round(svc.score(X_test, y_test), 4))
# Check the prediction time for a single sample
t=time.time()
n_predict = 10
print('My SVC predicts: ', svc.predict(X_test[0:n_predict]))
print('For these',n_predict, 'labels: ', y_test[0:n_predict])
t2 = time.time()
print(round(t2-t, 5), 'Seconds to predict', n_predict,'labels with SVC')
# Out:
# 307.67 Seconds to train SVC...
# Test Accuracy of SVC =  0.9319
# My SVC predicts:  [0. 1. 0. 1. 1. 0. 1. 0. 0. 0.]
# For these 10 labels:  [0. 1. 0. 1. 1. 0. 1. 0. 0. 0.]
# 0.21149 Seconds to predict 10 labels with SVC

# %%
"""
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
svr = SVC()
clf = GridSearchCV(svr, parameters)
clf.fit(X_train, y_train)
"""
# Out:
# "\nparameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}\nsvr = SVC()\nclf = GridSearchCV(svr, parameters)\nclf.fit(X_train, y_train)\n"

# %% [markdown]
# ## Xgboost

# %%
import xgboost as xgb
# read in data
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
model = xgb.XGBClassifier(
 learning_rate =0.1,
 n_estimators=150,
 max_depth=5,
 min_child_weight=1,
 gamma=0,
 subsample=0.75,
 colsample_bytree=0.75,
 objective= 'binary:logistic',
 nthread=8,
 scale_pos_weight=1)
eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train, eval_metric=["error", "logloss"], eval_set=eval_set, verbose=True, )
# Out:
# [0]	validation_0-error:0.126337	validation_0-logloss:0.634043	validation_1-error:0.14527	validation_1-logloss:0.637271
# [1]	validation_0-error:0.102759	validation_0-logloss:0.583632	validation_1-error:0.121903	validation_1-logloss:0.589356
# [2]	validation_0-error:0.087275	validation_0-logloss:0.540288	validation_1-error:0.107827	validation_1-logloss:0.549494
# [3]	validation_0-error:0.080166	validation_0-logloss:0.502135	validation_1-error:0.096847	validation_1-logloss:0.513252
# [4]	validation_0-error:0.072635	validation_0-logloss:0.468094	validation_1-error:0.096847	validation_1-logloss:0.480939
# [5]	validation_0-error:0.069961	validation_0-logloss:0.438112	validation_1-error:0.094313	validation_1-logloss:0.453241
# [6]	validation_0-error:0.064752	validation_0-logloss:0.411476	validation_1-error:0.090935	validation_1-logloss:0.428168
# [7]	validation_0-error:0.06257	validation_0-logloss:0.386207	validation_1-error:0.084178	validation_1-logloss:0.404905
# [8]	validation_0-error:0.056166	validation_0-logloss:0.364262	validation_1-error:0.083333	validation_1-logloss:0.384449
# [9]	validation_0-error:0.053843	validation_0-logloss:0.344084	validation_1-error:0.08277	validation_1-logloss:0.36601
# [10]	validation_0-error:0.052013	validation_0-logloss:0.326111	validation_1-error:0.081363	validation_1-logloss:0.349399
# [11]	validation_0-error:0.049479	validation_0-logloss:0.309358	validation_1-error:0.076295	validation_1-logloss:0.334077
# [12]	validation_0-error:0.048212	validation_0-logloss:0.294304	validation_1-error:0.07545	validation_1-logloss:0.319089
# [13]	validation_0-error:0.046523	validation_0-logloss:0.279882	validation_1-error:0.070101	validation_1-logloss:0.305327
# [14]	validation_0-error:0.045045	validation_0-logloss:0.266423	validation_1-error:0.069538	validation_1-logloss:0.29324
# [15]	validation_0-error:0.042934	validation_0-logloss:0.253874	validation_1-error:0.066723	validation_1-logloss:0.28131
# [16]	validation_0-error:0.041174	validation_0-logloss:0.242224	validation_1-error:0.065315	validation_1-logloss:0.270965
# [17]	validation_0-error:0.040189	validation_0-logloss:0.232111	validation_1-error:0.063908	validation_1-logloss:0.261656
# [18]	validation_0-error:0.038851	validation_0-logloss:0.222787	validation_1-error:0.065034	validation_1-logloss:0.253055
# [19]	validation_0-error:0.037303	validation_0-logloss:0.213289	validation_1-error:0.0625	validation_1-logloss:0.244117
# [20]	validation_0-error:0.035614	validation_0-logloss:0.205052	validation_1-error:0.0625	validation_1-logloss:0.236609
# [21]	validation_0-error:0.034769	validation_0-logloss:0.19715	validation_1-error:0.060811	validation_1-logloss:0.229454
# [22]	validation_0-error:0.033361	validation_0-logloss:0.189748	validation_1-error:0.057151	validation_1-logloss:0.222692
# [23]	validation_0-error:0.031743	validation_0-logloss:0.182328	validation_1-error:0.056306	validation_1-logloss:0.215585
# [24]	validation_0-error:0.030828	validation_0-logloss:0.175338	validation_1-error:0.056869	validation_1-logloss:0.209345
# [25]	validation_0-error:0.030194	validation_0-logloss:0.169269	validation_1-error:0.056025	validation_1-logloss:0.203969
# [26]	validation_0-error:0.02935	validation_0-logloss:0.163613	validation_1-error:0.055743	validation_1-logloss:0.198788
# [27]	validation_0-error:0.027309	validation_0-logloss:0.157483	validation_1-error:0.056306	validation_1-logloss:0.193343
# [28]	validation_0-error:0.026394	validation_0-logloss:0.151862	validation_1-error:0.053491	validation_1-logloss:0.188092
# [29]	validation_0-error:0.024986	validation_0-logloss:0.146876	validation_1-error:0.051802	validation_1-logloss:0.183616
# [30]	validation_0-error:0.023719	validation_0-logloss:0.142222	validation_1-error:0.052083	validation_1-logloss:0.17944
# [31]	validation_0-error:0.022734	validation_0-logloss:0.137938	validation_1-error:0.049831	validation_1-logloss:0.17582
# [32]	validation_0-error:0.022171	validation_0-logloss:0.13379	validation_1-error:0.050113	validation_1-logloss:0.171896
# [33]	validation_0-error:0.021256	validation_0-logloss:0.129138	validation_1-error:0.04955	validation_1-logloss:0.167817
# [34]	validation_0-error:0.0202	validation_0-logloss:0.124993	validation_1-error:0.048423	validation_1-logloss:0.164508
# [35]	validation_0-error:0.019355	validation_0-logloss:0.120834	validation_1-error:0.048142	validation_1-logloss:0.160986
# [36]	validation_0-error:0.018722	validation_0-logloss:0.116916	validation_1-error:0.048705	validation_1-logloss:0.157744
# [37]	validation_0-error:0.017948	validation_0-logloss:0.112969	validation_1-error:0.046171	validation_1-logloss:0.154664
# [38]	validation_0-error:0.016822	validation_0-logloss:0.109534	validation_1-error:0.046171	validation_1-logloss:0.151356
# [39]	validation_0-error:0.016329	validation_0-logloss:0.106162	validation_1-error:0.045045	validation_1-logloss:0.148394
# [40]	validation_0-error:0.015836	validation_0-logloss:0.102966	validation_1-error:0.045327	validation_1-logloss:0.145535
# [41]	validation_0-error:0.01478	validation_0-logloss:0.099738	validation_1-error:0.043356	validation_1-logloss:0.142657
# [42]	validation_0-error:0.014358	validation_0-logloss:0.096792	validation_1-error:0.042793	validation_1-logloss:0.140303
# [43]	validation_0-error:0.013654	validation_0-logloss:0.094272	validation_1-error:0.041385	validation_1-logloss:0.137665
# [44]	validation_0-error:0.01281	validation_0-logloss:0.09155	validation_1-error:0.041385	validation_1-logloss:0.13527
# [45]	validation_0-error:0.011895	validation_0-logloss:0.089019	validation_1-error:0.041948	validation_1-logloss:0.133467
# [46]	validation_0-error:0.01098	validation_0-logloss:0.086116	validation_1-error:0.041104	validation_1-logloss:0.131125
# [47]	validation_0-error:0.010839	validation_0-logloss:0.083965	validation_1-error:0.040259	validation_1-logloss:0.129141
# [48]	validation_0-error:0.010135	validation_0-logloss:0.081887	validation_1-error:0.039977	validation_1-logloss:0.12738
# [49]	validation_0-error:0.009783	validation_0-logloss:0.079828	validation_1-error:0.040541	validation_1-logloss:0.125788
# [50]	validation_0-error:0.009431	validation_0-logloss:0.077685	validation_1-error:0.039414	validation_1-logloss:0.124091
# [51]	validation_0-error:0.008939	validation_0-logloss:0.075603	validation_1-error:0.039414	validation_1-logloss:0.122213
# [52]	validation_0-error:0.008868	validation_0-logloss:0.073493	validation_1-error:0.03857	validation_1-logloss:0.120203
# [53]	validation_0-error:0.008516	validation_0-logloss:0.071199	validation_1-error:0.03857	validation_1-logloss:0.118303
# [54]	validation_0-error:0.007883	validation_0-logloss:0.069341	validation_1-error:0.03857	validation_1-logloss:0.116717
# [55]	validation_0-error:0.007531	validation_0-logloss:0.067239	validation_1-error:0.036881	validation_1-logloss:0.11456
# [56]	validation_0-error:0.007109	validation_0-logloss:0.065697	validation_1-error:0.036318	validation_1-logloss:0.112761
# [57]	validation_0-error:0.006546	validation_0-logloss:0.06377	validation_1-error:0.036318	validation_1-logloss:0.111023
# [58]	validation_0-error:0.006475	validation_0-logloss:0.062253	validation_1-error:0.035473	validation_1-logloss:0.109975
# [59]	validation_0-error:0.005771	validation_0-logloss:0.060485	validation_1-error:0.034628	validation_1-logloss:0.108709
# [60]	validation_0-error:0.005842	validation_0-logloss:0.059211	validation_1-error:0.034628	validation_1-logloss:0.107686
# [61]	validation_0-error:0.005912	validation_0-logloss:0.057711	validation_1-error:0.034628	validation_1-logloss:0.106638
# [62]	validation_0-error:0.005279	validation_0-logloss:0.056151	validation_1-error:0.033784	validation_1-logloss:0.105032
# [63]	validation_0-error:0.005349	validation_0-logloss:0.05486	validation_1-error:0.033502	validation_1-logloss:0.103909
# [64]	validation_0-error:0.004716	validation_0-logloss:0.053421	validation_1-error:0.032095	validation_1-logloss:0.102687
# [65]	validation_0-error:0.004645	validation_0-logloss:0.051822	validation_1-error:0.032658	validation_1-logloss:0.100949
# [66]	validation_0-error:0.004505	validation_0-logloss:0.050463	validation_1-error:0.033221	validation_1-logloss:0.099776
# [67]	validation_0-error:0.004293	validation_0-logloss:0.049167	validation_1-error:0.031813	validation_1-logloss:0.098346
# [68]	validation_0-error:0.003801	validation_0-logloss:0.047808	validation_1-error:0.032939	validation_1-logloss:0.097214
# [69]	validation_0-error:0.004012	validation_0-logloss:0.046822	validation_1-error:0.031532	validation_1-logloss:0.096009
# [70]	validation_0-error:0.00373	validation_0-logloss:0.045832	validation_1-error:0.031813	validation_1-logloss:0.095248
# [71]	validation_0-error:0.003519	validation_0-logloss:0.044949	validation_1-error:0.030124	validation_1-logloss:0.094239
# [72]	validation_0-error:0.003097	validation_0-logloss:0.043893	validation_1-error:0.028998	validation_1-logloss:0.093012
# [73]	validation_0-error:0.003026	validation_0-logloss:0.042628	validation_1-error:0.028716	validation_1-logloss:0.091781
# [74]	validation_0-error:0.002815	validation_0-logloss:0.04171	validation_1-error:0.029279	validation_1-logloss:0.090624
# [75]	validation_0-error:0.002745	validation_0-logloss:0.040846	validation_1-error:0.029561	validation_1-logloss:0.089904
# [76]	validation_0-error:0.002534	validation_0-logloss:0.039656	validation_1-error:0.028435	validation_1-logloss:0.088484
# [77]	validation_0-error:0.002323	validation_0-logloss:0.038577	validation_1-error:0.028153	validation_1-logloss:0.087521
# [78]	validation_0-error:0.002041	validation_0-logloss:0.037519	validation_1-error:0.028435	validation_1-logloss:0.08671
# [79]	validation_0-error:0.001971	validation_0-logloss:0.036507	validation_1-error:0.02759	validation_1-logloss:0.085617
# [80]	validation_0-error:0.0019	validation_0-logloss:0.035719	validation_1-error:0.027872	validation_1-logloss:0.084723
# [81]	validation_0-error:0.001689	validation_0-logloss:0.034759	validation_1-error:0.028435	validation_1-logloss:0.083631
# [82]	validation_0-error:0.00183	validation_0-logloss:0.033927	validation_1-error:0.02759	validation_1-logloss:0.082758
# [83]	validation_0-error:0.001619	validation_0-logloss:0.033048	validation_1-error:0.026745	validation_1-logloss:0.082152
# [84]	validation_0-error:0.001619	validation_0-logloss:0.032172	validation_1-error:0.026745	validation_1-logloss:0.081182
# [85]	validation_0-error:0.001619	validation_0-logloss:0.031356	validation_1-error:0.027027	validation_1-logloss:0.080421
# [86]	validation_0-error:0.001478	validation_0-logloss:0.030628	validation_1-error:0.026182	validation_1-logloss:0.079584
# [87]	validation_0-error:0.001478	validation_0-logloss:0.030019	validation_1-error:0.025901	validation_1-logloss:0.078774
# [88]	validation_0-error:0.001478	validation_0-logloss:0.029234	validation_1-error:0.026745	validation_1-logloss:0.077632
# [89]	validation_0-error:0.001408	validation_0-logloss:0.028651	validation_1-error:0.026182	validation_1-logloss:0.077001
# [90]	validation_0-error:0.001197	validation_0-logloss:0.028149	validation_1-error:0.026464	validation_1-logloss:0.076644
# [91]	validation_0-error:0.001337	validation_0-logloss:0.027636	validation_1-error:0.025619	validation_1-logloss:0.076128
# [92]	validation_0-error:0.001056	validation_0-logloss:0.026897	validation_1-error:0.026182	validation_1-logloss:0.075749
# [93]	validation_0-error:0.000915	validation_0-logloss:0.026265	validation_1-error:0.025901	validation_1-logloss:0.075032
# [94]	validation_0-error:0.000915	validation_0-logloss:0.025624	validation_1-error:0.025056	validation_1-logloss:0.074169
# [95]	validation_0-error:0.000915	validation_0-logloss:0.025093	validation_1-error:0.025338	validation_1-logloss:0.073624
# [96]	validation_0-error:0.000845	validation_0-logloss:0.024621	validation_1-error:0.025338	validation_1-logloss:0.073253
# [97]	validation_0-error:0.000774	validation_0-logloss:0.024147	validation_1-error:0.024775	validation_1-logloss:0.072799
# [98]	validation_0-error:0.000704	validation_0-logloss:0.023529	validation_1-error:0.02393	validation_1-logloss:0.072408
# [99]	validation_0-error:0.000563	validation_0-logloss:0.023005	validation_1-error:0.02393	validation_1-logloss:0.071795
# [100]	validation_0-error:0.000563	validation_0-logloss:0.02248	validation_1-error:0.024493	validation_1-logloss:0.07115
# [101]	validation_0-error:0.000563	validation_0-logloss:0.022022	validation_1-error:0.023086	validation_1-logloss:0.070418
# [102]	validation_0-error:0.000563	validation_0-logloss:0.021646	validation_1-error:0.023367	validation_1-logloss:0.070008
# [103]	validation_0-error:0.000563	validation_0-logloss:0.021156	validation_1-error:0.023367	validation_1-logloss:0.069357
# [104]	validation_0-error:0.000633	validation_0-logloss:0.020741	validation_1-error:0.023649	validation_1-logloss:0.068985
# [105]	validation_0-error:0.000493	validation_0-logloss:0.020217	validation_1-error:0.023367	validation_1-logloss:0.068425
# [106]	validation_0-error:0.000633	validation_0-logloss:0.019774	validation_1-error:0.022804	validation_1-logloss:0.068019
# [107]	validation_0-error:0.000422	validation_0-logloss:0.01939	validation_1-error:0.023086	validation_1-logloss:0.067743
# [108]	validation_0-error:0.000493	validation_0-logloss:0.019084	validation_1-error:0.023086	validation_1-logloss:0.067452
# [109]	validation_0-error:0.000493	validation_0-logloss:0.018706	validation_1-error:0.022241	validation_1-logloss:0.066743
# [110]	validation_0-error:0.000422	validation_0-logloss:0.018308	validation_1-error:0.022523	validation_1-logloss:0.066408
# [111]	validation_0-error:0.000352	validation_0-logloss:0.017863	validation_1-error:0.022804	validation_1-logloss:0.066003
# [112]	validation_0-error:0.000282	validation_0-logloss:0.01745	validation_1-error:0.023086	validation_1-logloss:0.065621
# [113]	validation_0-error:0.000282	validation_0-logloss:0.017092	validation_1-error:0.022523	validation_1-logloss:0.065137
# [114]	validation_0-error:0.000282	validation_0-logloss:0.016728	validation_1-error:0.022804	validation_1-logloss:0.064472
# [115]	validation_0-error:0.000211	validation_0-logloss:0.016484	validation_1-error:0.021678	validation_1-logloss:0.064257
# [116]	validation_0-error:0.000282	validation_0-logloss:0.016184	validation_1-error:0.021678	validation_1-logloss:0.064077
# [117]	validation_0-error:0.000211	validation_0-logloss:0.015884	validation_1-error:0.022523	validation_1-logloss:0.06391
# [118]	validation_0-error:0.000282	validation_0-logloss:0.015623	validation_1-error:0.022804	validation_1-logloss:0.063584
# [119]	validation_0-error:0.000211	validation_0-logloss:0.015255	validation_1-error:0.021959	validation_1-logloss:0.063275
# [120]	validation_0-error:0.000141	validation_0-logloss:0.014962	validation_1-error:0.021396	validation_1-logloss:0.062817
# [121]	validation_0-error:0.000141	validation_0-logloss:0.01476	validation_1-error:0.021678	validation_1-logloss:0.06258
# [122]	validation_0-error:0.000141	validation_0-logloss:0.014484	validation_1-error:0.021396	validation_1-logloss:0.062272
# [123]	validation_0-error:0.000141	validation_0-logloss:0.014152	validation_1-error:0.021396	validation_1-logloss:0.061893
# [124]	validation_0-error:0.000141	validation_0-logloss:0.013903	validation_1-error:0.021678	validation_1-logloss:0.061698
# [125]	validation_0-error:0.000141	validation_0-logloss:0.013623	validation_1-error:0.021678	validation_1-logloss:0.061476
# [126]	validation_0-error:0.000141	validation_0-logloss:0.013316	validation_1-error:0.021115	validation_1-logloss:0.061144
# [127]	validation_0-error:0.000141	validation_0-logloss:0.01309	validation_1-error:0.021115	validation_1-logloss:0.060776
# [128]	validation_0-error:7e-05	validation_0-logloss:0.012849	validation_1-error:0.021396	validation_1-logloss:0.060629
# [129]	validation_0-error:7e-05	validation_0-logloss:0.012646	validation_1-error:0.021678	validation_1-logloss:0.060498
# [130]	validation_0-error:7e-05	validation_0-logloss:0.012369	validation_1-error:0.021678	validation_1-logloss:0.060202
# [131]	validation_0-error:7e-05	validation_0-logloss:0.012148	validation_1-error:0.021115	validation_1-logloss:0.059885
# [132]	validation_0-error:0	validation_0-logloss:0.011882	validation_1-error:0.021115	validation_1-logloss:0.05965
# [133]	validation_0-error:0	validation_0-logloss:0.011685	validation_1-error:0.021115	validation_1-logloss:0.05929
# [134]	validation_0-error:0	validation_0-logloss:0.011525	validation_1-error:0.020833	validation_1-logloss:0.05901
# [135]	validation_0-error:0	validation_0-logloss:0.011269	validation_1-error:0.020833	validation_1-logloss:0.058403
# [136]	validation_0-error:0	validation_0-logloss:0.011117	validation_1-error:0.021115	validation_1-logloss:0.058306
# [137]	validation_0-error:0	validation_0-logloss:0.010913	validation_1-error:0.020833	validation_1-logloss:0.058169
# [138]	validation_0-error:0	validation_0-logloss:0.010746	validation_1-error:0.020552	validation_1-logloss:0.058136
# [139]	validation_0-error:0	validation_0-logloss:0.010561	validation_1-error:0.021115	validation_1-logloss:0.058032
# [140]	validation_0-error:0	validation_0-logloss:0.010319	validation_1-error:0.020833	validation_1-logloss:0.057646
# [141]	validation_0-error:0	validation_0-logloss:0.0101	validation_1-error:0.02027	validation_1-logloss:0.057353
# [142]	validation_0-error:0	validation_0-logloss:0.009923	validation_1-error:0.02027	validation_1-logloss:0.057166
# [143]	validation_0-error:0	validation_0-logloss:0.00976	validation_1-error:0.02027	validation_1-logloss:0.056975
# [144]	validation_0-error:0	validation_0-logloss:0.009606	validation_1-error:0.020552	validation_1-logloss:0.056728
# [145]	validation_0-error:0	validation_0-logloss:0.009407	validation_1-error:0.020552	validation_1-logloss:0.056339
# [146]	validation_0-error:0	validation_0-logloss:0.009197	validation_1-error:0.020552	validation_1-logloss:0.055997
# [147]	validation_0-error:0	validation_0-logloss:0.009004	validation_1-error:0.020552	validation_1-logloss:0.055828
# [148]	validation_0-error:0	validation_0-logloss:0.008834	validation_1-error:0.020552	validation_1-logloss:0.055365
# [149]	validation_0-error:0	validation_0-logloss:0.008677	validation_1-error:0.02027	validation_1-logloss:0.054999
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.75, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=5, min_child_weight=1, missing=None, n_estimators=150,
#        n_jobs=1, nthread=8, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.75)

# %%
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 97.97%
# /home/xnguyen/.local/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# save model to file
pickle.dump((model, X_scaler), open("xgboost_classifier_small.pkl", "wb"))

# %%
# retrieve performance metrics
def plot_model_learning_curve(model):
    results = model.evals_result()
    epochs = len(results['validation_0']['error'])
    x_axis = range(0, epochs)
    # plot log loss
    plt.figure(figsize=(10,5))
    
    ax = plt.subplot(1,2,1)
    ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
    ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
    ax.legend()
    plt.ylabel('Log Loss')
    plt.title('XGBoost Log Loss')

    # plot classification error
    ax = plt.subplot(1,2,2)
    ax.plot(x_axis, results['validation_0']['error'], label='Train')
    ax.plot(x_axis, results['validation_1']['error'], label='Test')
    ax.legend()
    plt.ylabel('Classification Error')
    plt.title('XGBoost Classification Error')
    plt.show()
plot_model_learning_curve(model)

# %%
model2 = xgb.XGBClassifier(
 learning_rate = 0.05,
 n_estimators=1000,
 max_depth=3,
 min_child_weight=1,
 gamma=0,
 subsample=0.5,
 colsample_bytree=0.5,
 objective= 'binary:logistic',
 nthread=12,
 scale_pos_weight=1)
eval_set = [(X_train, y_train), (X_test, y_test)]
model2.fit(X_train, y_train, eval_metric=["error", "logloss"], eval_set=eval_set, verbose=True, )
# Out:
# [0]	validation_0-error:0.19299	validation_0-logloss:0.670123	validation_1-error:0.206363	validation_1-logloss:0.670532
# [1]	validation_0-error:0.160051	validation_0-logloss:0.64873	validation_1-error:0.164133	validation_1-logloss:0.649409
# [2]	validation_0-error:0.143933	validation_0-logloss:0.628953	validation_1-error:0.158502	validation_1-logloss:0.630349
# [3]	validation_0-error:0.135135	validation_0-logloss:0.610017	validation_1-error:0.15259	validation_1-logloss:0.612095
# [4]	validation_0-error:0.12859	validation_0-logloss:0.592913	validation_1-error:0.142455	validation_1-logloss:0.595292
# [5]	validation_0-error:0.122607	validation_0-logloss:0.57656	validation_1-error:0.132038	validation_1-logloss:0.578808
# [6]	validation_0-error:0.114865	validation_0-logloss:0.560819	validation_1-error:0.123311	validation_1-logloss:0.563509
# [7]	validation_0-error:0.116273	validation_0-logloss:0.546127	validation_1-error:0.126971	validation_1-logloss:0.549453
# [8]	validation_0-error:0.113035	validation_0-logloss:0.531809	validation_1-error:0.119369	validation_1-logloss:0.535414
# [9]	validation_0-error:0.109868	validation_0-logloss:0.518306	validation_1-error:0.119369	validation_1-logloss:0.52195
# [10]	validation_0-error:0.105645	validation_0-logloss:0.505838	validation_1-error:0.118243	validation_1-logloss:0.509806
# [11]	validation_0-error:0.105856	validation_0-logloss:0.493778	validation_1-error:0.113457	validation_1-logloss:0.498014
# [12]	validation_0-error:0.103674	validation_0-logloss:0.482093	validation_1-error:0.113739	validation_1-logloss:0.486574
# [13]	validation_0-error:0.100929	validation_0-logloss:0.471037	validation_1-error:0.10839	validation_1-logloss:0.475797
# [14]	validation_0-error:0.101422	validation_0-logloss:0.460905	validation_1-error:0.108671	validation_1-logloss:0.466002
# [15]	validation_0-error:0.099803	validation_0-logloss:0.451257	validation_1-error:0.1067	validation_1-logloss:0.456897
# [16]	validation_0-error:0.098043	validation_0-logloss:0.441735	validation_1-error:0.102759	validation_1-logloss:0.447557
# [17]	validation_0-error:0.096425	validation_0-logloss:0.432783	validation_1-error:0.103322	validation_1-logloss:0.438924
# [18]	validation_0-error:0.094313	validation_0-logloss:0.424468	validation_1-error:0.103604	validation_1-logloss:0.43115
# [19]	validation_0-error:0.09368	validation_0-logloss:0.415867	validation_1-error:0.103885	validation_1-logloss:0.42273
# [20]	validation_0-error:0.091427	validation_0-logloss:0.407607	validation_1-error:0.100788	validation_1-logloss:0.414444
# [21]	validation_0-error:0.090864	validation_0-logloss:0.400008	validation_1-error:0.098536	validation_1-logloss:0.407232
# [22]	validation_0-error:0.089949	validation_0-logloss:0.392767	validation_1-error:0.098536	validation_1-logloss:0.400263
# [23]	validation_0-error:0.087486	validation_0-logloss:0.385014	validation_1-error:0.095721	validation_1-logloss:0.392705
# [24]	validation_0-error:0.086712	validation_0-logloss:0.378528	validation_1-error:0.09741	validation_1-logloss:0.386697
# [25]	validation_0-error:0.085586	validation_0-logloss:0.371736	validation_1-error:0.096284	validation_1-logloss:0.379989
# [26]	validation_0-error:0.084178	validation_0-logloss:0.365123	validation_1-error:0.095158	validation_1-logloss:0.373742
# [27]	validation_0-error:0.083544	validation_0-logloss:0.358849	validation_1-error:0.092061	validation_1-logloss:0.367425
# [28]	validation_0-error:0.082278	validation_0-logloss:0.352993	validation_1-error:0.090935	validation_1-logloss:0.3617
# [29]	validation_0-error:0.081574	validation_0-logloss:0.346984	validation_1-error:0.091779	validation_1-logloss:0.35609
# [30]	validation_0-error:0.080307	validation_0-logloss:0.341305	validation_1-error:0.088682	validation_1-logloss:0.350322
# [31]	validation_0-error:0.07904	validation_0-logloss:0.335716	validation_1-error:0.088964	validation_1-logloss:0.345083
# [32]	validation_0-error:0.077351	validation_0-logloss:0.330393	validation_1-error:0.086993	validation_1-logloss:0.339912
# [33]	validation_0-error:0.076295	validation_0-logloss:0.325044	validation_1-error:0.086149	validation_1-logloss:0.335111
# [34]	validation_0-error:0.07531	validation_0-logloss:0.320069	validation_1-error:0.083615	validation_1-logloss:0.330116
# [35]	validation_0-error:0.07531	validation_0-logloss:0.315433	validation_1-error:0.081926	validation_1-logloss:0.325629
# [36]	validation_0-error:0.074043	validation_0-logloss:0.31037	validation_1-error:0.081644	validation_1-logloss:0.320843
# [37]	validation_0-error:0.072846	validation_0-logloss:0.305551	validation_1-error:0.0808	validation_1-logloss:0.316332
# [38]	validation_0-error:0.071931	validation_0-logloss:0.301021	validation_1-error:0.080236	validation_1-logloss:0.312025
# [39]	validation_0-error:0.070805	validation_0-logloss:0.296473	validation_1-error:0.078266	validation_1-logloss:0.307754
# [40]	validation_0-error:0.069398	validation_0-logloss:0.292274	validation_1-error:0.076295	validation_1-logloss:0.303642
# [41]	validation_0-error:0.069468	validation_0-logloss:0.288307	validation_1-error:0.076014	validation_1-logloss:0.29976
# [42]	validation_0-error:0.068623	validation_0-logloss:0.283971	validation_1-error:0.076577	validation_1-logloss:0.295786
# [43]	validation_0-error:0.067005	validation_0-logloss:0.280301	validation_1-error:0.074606	validation_1-logloss:0.292308
# [44]	validation_0-error:0.066582	validation_0-logloss:0.276588	validation_1-error:0.076577	validation_1-logloss:0.28892
# [45]	validation_0-error:0.066653	validation_0-logloss:0.273168	validation_1-error:0.076014	validation_1-logloss:0.285527
# [46]	validation_0-error:0.065949	validation_0-logloss:0.269781	validation_1-error:0.07348	validation_1-logloss:0.282337
# [47]	validation_0-error:0.06433	validation_0-logloss:0.266443	validation_1-error:0.072635	validation_1-logloss:0.279624
# [48]	validation_0-error:0.063274	validation_0-logloss:0.263384	validation_1-error:0.072917	validation_1-logloss:0.276835
# [49]	validation_0-error:0.063063	validation_0-logloss:0.259913	validation_1-error:0.07348	validation_1-logloss:0.27351
# [50]	validation_0-error:0.062289	validation_0-logloss:0.256601	validation_1-error:0.071509	validation_1-logloss:0.270362
# [51]	validation_0-error:0.061937	validation_0-logloss:0.25364	validation_1-error:0.072072	validation_1-logloss:0.267591
# [52]	validation_0-error:0.061444	validation_0-logloss:0.250498	validation_1-error:0.072635	validation_1-logloss:0.264793
# [53]	validation_0-error:0.059403	validation_0-logloss:0.247585	validation_1-error:0.071509	validation_1-logloss:0.261865
# [54]	validation_0-error:0.058559	validation_0-logloss:0.245002	validation_1-error:0.071791	validation_1-logloss:0.259228
# [55]	validation_0-error:0.059474	validation_0-logloss:0.242078	validation_1-error:0.071227	validation_1-logloss:0.256534
# [56]	validation_0-error:0.05877	validation_0-logloss:0.239256	validation_1-error:0.071227	validation_1-logloss:0.253671
# [57]	validation_0-error:0.057644	validation_0-logloss:0.23649	validation_1-error:0.070383	validation_1-logloss:0.25115
# [58]	validation_0-error:0.057432	validation_0-logloss:0.234052	validation_1-error:0.071509	validation_1-logloss:0.248801
# [59]	validation_0-error:0.057503	validation_0-logloss:0.231453	validation_1-error:0.072072	validation_1-logloss:0.246394
# [60]	validation_0-error:0.05701	validation_0-logloss:0.229013	validation_1-error:0.068975	validation_1-logloss:0.244132
# [61]	validation_0-error:0.056517	validation_0-logloss:0.226856	validation_1-error:0.070101	validation_1-logloss:0.242164
# [62]	validation_0-error:0.056447	validation_0-logloss:0.224669	validation_1-error:0.068694	validation_1-logloss:0.240148
# [63]	validation_0-error:0.056166	validation_0-logloss:0.222406	validation_1-error:0.067568	validation_1-logloss:0.237977
# [64]	validation_0-error:0.055532	validation_0-logloss:0.220099	validation_1-error:0.065597	validation_1-logloss:0.235932
# [65]	validation_0-error:0.05518	validation_0-logloss:0.217882	validation_1-error:0.068412	validation_1-logloss:0.233863
# [66]	validation_0-error:0.054054	validation_0-logloss:0.215356	validation_1-error:0.067849	validation_1-logloss:0.231775
# [67]	validation_0-error:0.053491	validation_0-logloss:0.21305	validation_1-error:0.066441	validation_1-logloss:0.229726
# [68]	validation_0-error:0.052576	validation_0-logloss:0.210838	validation_1-error:0.065878	validation_1-logloss:0.227763
# [69]	validation_0-error:0.052154	validation_0-logloss:0.208741	validation_1-error:0.066723	validation_1-logloss:0.22604
# [70]	validation_0-error:0.051309	validation_0-logloss:0.206647	validation_1-error:0.065315	validation_1-logloss:0.224326
# [71]	validation_0-error:0.051661	validation_0-logloss:0.204888	validation_1-error:0.065878	validation_1-logloss:0.222827
# [72]	validation_0-error:0.051239	validation_0-logloss:0.203049	validation_1-error:0.065597	validation_1-logloss:0.221061
# [73]	validation_0-error:0.050746	validation_0-logloss:0.201187	validation_1-error:0.064752	validation_1-logloss:0.219292
# [74]	validation_0-error:0.050324	validation_0-logloss:0.199125	validation_1-error:0.065597	validation_1-logloss:0.217391
# [75]	validation_0-error:0.049831	validation_0-logloss:0.197384	validation_1-error:0.062782	validation_1-logloss:0.215765
# [76]	validation_0-error:0.048775	validation_0-logloss:0.195068	validation_1-error:0.062218	validation_1-logloss:0.213349
# [77]	validation_0-error:0.049057	validation_0-logloss:0.193124	validation_1-error:0.062782	validation_1-logloss:0.211585
# [78]	validation_0-error:0.048353	validation_0-logloss:0.191232	validation_1-error:0.060529	validation_1-logloss:0.210007
# [79]	validation_0-error:0.047649	validation_0-logloss:0.189592	validation_1-error:0.060811	validation_1-logloss:0.208342
# [80]	validation_0-error:0.048142	validation_0-logloss:0.187904	validation_1-error:0.059966	validation_1-logloss:0.206925
# [81]	validation_0-error:0.046875	validation_0-logloss:0.186082	validation_1-error:0.059122	validation_1-logloss:0.20491
# [82]	validation_0-error:0.046101	validation_0-logloss:0.184292	validation_1-error:0.058277	validation_1-logloss:0.203438
# [83]	validation_0-error:0.045115	validation_0-logloss:0.182665	validation_1-error:0.058559	validation_1-logloss:0.201841
# [84]	validation_0-error:0.044904	validation_0-logloss:0.181158	validation_1-error:0.058559	validation_1-logloss:0.200366
# [85]	validation_0-error:0.044904	validation_0-logloss:0.179535	validation_1-error:0.057995	validation_1-logloss:0.198873
# [86]	validation_0-error:0.044552	validation_0-logloss:0.178068	validation_1-error:0.058559	validation_1-logloss:0.197361
# [87]	validation_0-error:0.044412	validation_0-logloss:0.176637	validation_1-error:0.056869	validation_1-logloss:0.195944
# [88]	validation_0-error:0.043778	validation_0-logloss:0.175015	validation_1-error:0.056306	validation_1-logloss:0.194569
# [89]	validation_0-error:0.043426	validation_0-logloss:0.173396	validation_1-error:0.056869	validation_1-logloss:0.193072
# [90]	validation_0-error:0.043497	validation_0-logloss:0.172241	validation_1-error:0.055462	validation_1-logloss:0.192095
# [91]	validation_0-error:0.043285	validation_0-logloss:0.170809	validation_1-error:0.056025	validation_1-logloss:0.190751
# [92]	validation_0-error:0.042652	validation_0-logloss:0.169607	validation_1-error:0.056869	validation_1-logloss:0.18958
# [93]	validation_0-error:0.04223	validation_0-logloss:0.168149	validation_1-error:0.054054	validation_1-logloss:0.187893
# [94]	validation_0-error:0.041878	validation_0-logloss:0.166943	validation_1-error:0.05518	validation_1-logloss:0.186818
# [95]	validation_0-error:0.041315	validation_0-logloss:0.165637	validation_1-error:0.054054	validation_1-logloss:0.18543
# [96]	validation_0-error:0.040752	validation_0-logloss:0.164036	validation_1-error:0.054899	validation_1-logloss:0.184045
# [97]	validation_0-error:0.040259	validation_0-logloss:0.162723	validation_1-error:0.054617	validation_1-logloss:0.182744
# [98]	validation_0-error:0.039766	validation_0-logloss:0.161381	validation_1-error:0.054617	validation_1-logloss:0.18169
# [99]	validation_0-error:0.039203	validation_0-logloss:0.160018	validation_1-error:0.054336	validation_1-logloss:0.18052
# [100]	validation_0-error:0.039062	validation_0-logloss:0.158634	validation_1-error:0.054336	validation_1-logloss:0.179324
# [101]	validation_0-error:0.038922	validation_0-logloss:0.157452	validation_1-error:0.05518	validation_1-logloss:0.178395
# [102]	validation_0-error:0.03857	validation_0-logloss:0.156283	validation_1-error:0.054054	validation_1-logloss:0.177419
# [103]	validation_0-error:0.038429	validation_0-logloss:0.155072	validation_1-error:0.054054	validation_1-logloss:0.176282
# [104]	validation_0-error:0.038077	validation_0-logloss:0.153915	validation_1-error:0.054617	validation_1-logloss:0.175172
# [105]	validation_0-error:0.037584	validation_0-logloss:0.15281	validation_1-error:0.054336	validation_1-logloss:0.174265
# [106]	validation_0-error:0.037303	validation_0-logloss:0.151617	validation_1-error:0.054899	validation_1-logloss:0.173101
# [107]	validation_0-error:0.037162	validation_0-logloss:0.150242	validation_1-error:0.053773	validation_1-logloss:0.171851
# [108]	validation_0-error:0.036951	validation_0-logloss:0.149024	validation_1-error:0.052928	validation_1-logloss:0.170738
# [109]	validation_0-error:0.036388	validation_0-logloss:0.148045	validation_1-error:0.053209	validation_1-logloss:0.169933
# [110]	validation_0-error:0.036388	validation_0-logloss:0.146771	validation_1-error:0.052646	validation_1-logloss:0.169055
# [111]	validation_0-error:0.035543	validation_0-logloss:0.145764	validation_1-error:0.053209	validation_1-logloss:0.168079
# [112]	validation_0-error:0.035755	validation_0-logloss:0.144804	validation_1-error:0.05152	validation_1-logloss:0.167186
# [113]	validation_0-error:0.035332	validation_0-logloss:0.143894	validation_1-error:0.051802	validation_1-logloss:0.166396
# [114]	validation_0-error:0.034769	validation_0-logloss:0.143009	validation_1-error:0.052646	validation_1-logloss:0.165699
# [115]	validation_0-error:0.034699	validation_0-logloss:0.142206	validation_1-error:0.052365	validation_1-logloss:0.164968
# [116]	validation_0-error:0.034206	validation_0-logloss:0.141277	validation_1-error:0.052646	validation_1-logloss:0.164163
# [117]	validation_0-error:0.034136	validation_0-logloss:0.140253	validation_1-error:0.052365	validation_1-logloss:0.163173
# [118]	validation_0-error:0.033502	validation_0-logloss:0.13928	validation_1-error:0.053209	validation_1-logloss:0.16249
# [119]	validation_0-error:0.033784	validation_0-logloss:0.138343	validation_1-error:0.052365	validation_1-logloss:0.161566
# [120]	validation_0-error:0.033432	validation_0-logloss:0.137392	validation_1-error:0.051239	validation_1-logloss:0.160871
# [121]	validation_0-error:0.033502	validation_0-logloss:0.136552	validation_1-error:0.051239	validation_1-logloss:0.160149
# [122]	validation_0-error:0.032798	validation_0-logloss:0.13537	validation_1-error:0.052365	validation_1-logloss:0.159124
# [123]	validation_0-error:0.032517	validation_0-logloss:0.134626	validation_1-error:0.05152	validation_1-logloss:0.158292
# [124]	validation_0-error:0.032235	validation_0-logloss:0.133813	validation_1-error:0.051239	validation_1-logloss:0.157705
# [125]	validation_0-error:0.032024	validation_0-logloss:0.132674	validation_1-error:0.051239	validation_1-logloss:0.156779
# [126]	validation_0-error:0.030898	validation_0-logloss:0.131839	validation_1-error:0.05152	validation_1-logloss:0.155927
# [127]	validation_0-error:0.030687	validation_0-logloss:0.130914	validation_1-error:0.050676	validation_1-logloss:0.155214
# [128]	validation_0-error:0.030617	validation_0-logloss:0.129986	validation_1-error:0.051239	validation_1-logloss:0.154308
# [129]	validation_0-error:0.030687	validation_0-logloss:0.129256	validation_1-error:0.051239	validation_1-logloss:0.153735
# [130]	validation_0-error:0.030476	validation_0-logloss:0.128288	validation_1-error:0.050113	validation_1-logloss:0.152753
# [131]	validation_0-error:0.030335	validation_0-logloss:0.127272	validation_1-error:0.050676	validation_1-logloss:0.151739
# [132]	validation_0-error:0.029631	validation_0-logloss:0.12649	validation_1-error:0.050394	validation_1-logloss:0.151178
# [133]	validation_0-error:0.028927	validation_0-logloss:0.125401	validation_1-error:0.049831	validation_1-logloss:0.150167
# [134]	validation_0-error:0.028787	validation_0-logloss:0.124546	validation_1-error:0.049268	validation_1-logloss:0.149338
# [135]	validation_0-error:0.028575	validation_0-logloss:0.123495	validation_1-error:0.048986	validation_1-logloss:0.148516
# [136]	validation_0-error:0.028224	validation_0-logloss:0.122573	validation_1-error:0.048986	validation_1-logloss:0.14767
# [137]	validation_0-error:0.027872	validation_0-logloss:0.121809	validation_1-error:0.048705	validation_1-logloss:0.146791
# [138]	validation_0-error:0.02766	validation_0-logloss:0.121101	validation_1-error:0.049268	validation_1-logloss:0.145986
# [139]	validation_0-error:0.027731	validation_0-logloss:0.1205	validation_1-error:0.048423	validation_1-logloss:0.145406
# [140]	validation_0-error:0.02752	validation_0-logloss:0.119685	validation_1-error:0.04786	validation_1-logloss:0.144591
# [141]	validation_0-error:0.027097	validation_0-logloss:0.118823	validation_1-error:0.047579	validation_1-logloss:0.143616
# [142]	validation_0-error:0.027027	validation_0-logloss:0.118007	validation_1-error:0.047579	validation_1-logloss:0.142901
# [143]	validation_0-error:0.026886	validation_0-logloss:0.117425	validation_1-error:0.047297	validation_1-logloss:0.142385
# [144]	validation_0-error:0.026745	validation_0-logloss:0.116728	validation_1-error:0.046734	validation_1-logloss:0.141795
# [145]	validation_0-error:0.026886	validation_0-logloss:0.115995	validation_1-error:0.046453	validation_1-logloss:0.141122
# [146]	validation_0-error:0.026464	validation_0-logloss:0.115195	validation_1-error:0.046453	validation_1-logloss:0.140403
# [147]	validation_0-error:0.026464	validation_0-logloss:0.114534	validation_1-error:0.046171	validation_1-logloss:0.139657
# [148]	validation_0-error:0.026253	validation_0-logloss:0.113881	validation_1-error:0.047579	validation_1-logloss:0.1392
# [149]	validation_0-error:0.026253	validation_0-logloss:0.113285	validation_1-error:0.047016	validation_1-logloss:0.138799
# [150]	validation_0-error:0.025901	validation_0-logloss:0.112489	validation_1-error:0.047579	validation_1-logloss:0.138201
# [151]	validation_0-error:0.025479	validation_0-logloss:0.111888	validation_1-error:0.046734	validation_1-logloss:0.1377
# [152]	validation_0-error:0.024845	validation_0-logloss:0.111163	validation_1-error:0.047579	validation_1-logloss:0.136975
# [153]	validation_0-error:0.025056	validation_0-logloss:0.110686	validation_1-error:0.046171	validation_1-logloss:0.136509
# [154]	validation_0-error:0.024634	validation_0-logloss:0.11	validation_1-error:0.047297	validation_1-logloss:0.135981
# [155]	validation_0-error:0.024282	validation_0-logloss:0.109358	validation_1-error:0.047016	validation_1-logloss:0.13522
# [156]	validation_0-error:0.024001	validation_0-logloss:0.10862	validation_1-error:0.046453	validation_1-logloss:0.134616
# [157]	validation_0-error:0.023649	validation_0-logloss:0.107959	validation_1-error:0.046171	validation_1-logloss:0.134189
# [158]	validation_0-error:0.023508	validation_0-logloss:0.107316	validation_1-error:0.04589	validation_1-logloss:0.133696
# [159]	validation_0-error:0.023156	validation_0-logloss:0.106704	validation_1-error:0.046171	validation_1-logloss:0.133025
# [160]	validation_0-error:0.023015	validation_0-logloss:0.106165	validation_1-error:0.044764	validation_1-logloss:0.132531
# [161]	validation_0-error:0.023086	validation_0-logloss:0.105337	validation_1-error:0.044764	validation_1-logloss:0.131777
# [162]	validation_0-error:0.023156	validation_0-logloss:0.104727	validation_1-error:0.045045	validation_1-logloss:0.131245
# [163]	validation_0-error:0.022874	validation_0-logloss:0.104143	validation_1-error:0.0442	validation_1-logloss:0.130753
# [164]	validation_0-error:0.022593	validation_0-logloss:0.103512	validation_1-error:0.044482	validation_1-logloss:0.130305
# [165]	validation_0-error:0.022311	validation_0-logloss:0.102895	validation_1-error:0.043919	validation_1-logloss:0.129733
# [166]	validation_0-error:0.02203	validation_0-logloss:0.102195	validation_1-error:0.043356	validation_1-logloss:0.129006
# [167]	validation_0-error:0.021959	validation_0-logloss:0.101501	validation_1-error:0.043637	validation_1-logloss:0.128369
# [168]	validation_0-error:0.021889	validation_0-logloss:0.100943	validation_1-error:0.043356	validation_1-logloss:0.127861
# [169]	validation_0-error:0.021608	validation_0-logloss:0.100403	validation_1-error:0.043637	validation_1-logloss:0.127349
# [170]	validation_0-error:0.021467	validation_0-logloss:0.099731	validation_1-error:0.042793	validation_1-logloss:0.126696
# [171]	validation_0-error:0.021115	validation_0-logloss:0.099214	validation_1-error:0.042511	validation_1-logloss:0.126343
# [172]	validation_0-error:0.021185	validation_0-logloss:0.098685	validation_1-error:0.043637	validation_1-logloss:0.125783
# [173]	validation_0-error:0.020552	validation_0-logloss:0.098234	validation_1-error:0.043074	validation_1-logloss:0.125395
# [174]	validation_0-error:0.020552	validation_0-logloss:0.097625	validation_1-error:0.042793	validation_1-logloss:0.124985
# [175]	validation_0-error:0.020622	validation_0-logloss:0.09713	validation_1-error:0.041385	validation_1-logloss:0.124596
# [176]	validation_0-error:0.020411	validation_0-logloss:0.096534	validation_1-error:0.04223	validation_1-logloss:0.123977
# [177]	validation_0-error:0.020059	validation_0-logloss:0.095932	validation_1-error:0.041385	validation_1-logloss:0.123483
# [178]	validation_0-error:0.019566	validation_0-logloss:0.095188	validation_1-error:0.041667	validation_1-logloss:0.122774
# [179]	validation_0-error:0.019778	validation_0-logloss:0.094583	validation_1-error:0.040541	validation_1-logloss:0.122346
# [180]	validation_0-error:0.019496	validation_0-logloss:0.093992	validation_1-error:0.040259	validation_1-logloss:0.121679
# [181]	validation_0-error:0.019496	validation_0-logloss:0.093524	validation_1-error:0.039977	validation_1-logloss:0.121301
# [182]	validation_0-error:0.019003	validation_0-logloss:0.093159	validation_1-error:0.040541	validation_1-logloss:0.121012
# [183]	validation_0-error:0.019144	validation_0-logloss:0.092706	validation_1-error:0.040541	validation_1-logloss:0.120599
# [184]	validation_0-error:0.018863	validation_0-logloss:0.092303	validation_1-error:0.040822	validation_1-logloss:0.120259
# [185]	validation_0-error:0.019003	validation_0-logloss:0.091833	validation_1-error:0.041667	validation_1-logloss:0.119825
# [186]	validation_0-error:0.018581	validation_0-logloss:0.091356	validation_1-error:0.041104	validation_1-logloss:0.119532
# [187]	validation_0-error:0.018581	validation_0-logloss:0.090745	validation_1-error:0.040822	validation_1-logloss:0.119092
# [188]	validation_0-error:0.018511	validation_0-logloss:0.090102	validation_1-error:0.041104	validation_1-logloss:0.118478
# [189]	validation_0-error:0.018229	validation_0-logloss:0.089709	validation_1-error:0.041385	validation_1-logloss:0.118141
# [190]	validation_0-error:0.017807	validation_0-logloss:0.089099	validation_1-error:0.039977	validation_1-logloss:0.117681
# [191]	validation_0-error:0.018018	validation_0-logloss:0.088617	validation_1-error:0.039414	validation_1-logloss:0.117276
# [192]	validation_0-error:0.017666	validation_0-logloss:0.088263	validation_1-error:0.039414	validation_1-logloss:0.116883
# [193]	validation_0-error:0.017736	validation_0-logloss:0.08774	validation_1-error:0.039133	validation_1-logloss:0.116444
# [194]	validation_0-error:0.017525	validation_0-logloss:0.087257	validation_1-error:0.039133	validation_1-logloss:0.116008
# [195]	validation_0-error:0.017244	validation_0-logloss:0.086729	validation_1-error:0.039133	validation_1-logloss:0.115421
# [196]	validation_0-error:0.016962	validation_0-logloss:0.086229	validation_1-error:0.039133	validation_1-logloss:0.115068
# [197]	validation_0-error:0.017033	validation_0-logloss:0.085738	validation_1-error:0.039696	validation_1-logloss:0.114654
# [198]	validation_0-error:0.016822	validation_0-logloss:0.085348	validation_1-error:0.039133	validation_1-logloss:0.114412
# [199]	validation_0-error:0.016751	validation_0-logloss:0.084902	validation_1-error:0.038288	validation_1-logloss:0.113943
# [200]	validation_0-error:0.016751	validation_0-logloss:0.084594	validation_1-error:0.038007	validation_1-logloss:0.113735
# [201]	validation_0-error:0.016681	validation_0-logloss:0.084071	validation_1-error:0.037725	validation_1-logloss:0.113239
# [202]	validation_0-error:0.01654	validation_0-logloss:0.083594	validation_1-error:0.037725	validation_1-logloss:0.112904
# [203]	validation_0-error:0.016399	validation_0-logloss:0.083204	validation_1-error:0.037444	validation_1-logloss:0.112575
# [204]	validation_0-error:0.016258	validation_0-logloss:0.08282	validation_1-error:0.037725	validation_1-logloss:0.11229
# [205]	validation_0-error:0.015766	validation_0-logloss:0.082386	validation_1-error:0.038007	validation_1-logloss:0.111829
# [206]	validation_0-error:0.015555	validation_0-logloss:0.081838	validation_1-error:0.037444	validation_1-logloss:0.111301
# [207]	validation_0-error:0.015414	validation_0-logloss:0.081461	validation_1-error:0.037162	validation_1-logloss:0.110949
# [208]	validation_0-error:0.015414	validation_0-logloss:0.081083	validation_1-error:0.036881	validation_1-logloss:0.110733
# [209]	validation_0-error:0.015555	validation_0-logloss:0.080617	validation_1-error:0.037444	validation_1-logloss:0.110324
# [210]	validation_0-error:0.015343	validation_0-logloss:0.080087	validation_1-error:0.036881	validation_1-logloss:0.109829
# [211]	validation_0-error:0.015132	validation_0-logloss:0.079685	validation_1-error:0.036599	validation_1-logloss:0.109469
# [212]	validation_0-error:0.015132	validation_0-logloss:0.079426	validation_1-error:0.036599	validation_1-logloss:0.109294
# [213]	validation_0-error:0.014851	validation_0-logloss:0.079055	validation_1-error:0.036881	validation_1-logloss:0.108937
# [214]	validation_0-error:0.01478	validation_0-logloss:0.078613	validation_1-error:0.035755	validation_1-logloss:0.108705
# [215]	validation_0-error:0.014499	validation_0-logloss:0.078175	validation_1-error:0.035755	validation_1-logloss:0.108257
# [216]	validation_0-error:0.014499	validation_0-logloss:0.077763	validation_1-error:0.035473	validation_1-logloss:0.107912
# [217]	validation_0-error:0.014217	validation_0-logloss:0.077371	validation_1-error:0.035191	validation_1-logloss:0.107513
# [218]	validation_0-error:0.014358	validation_0-logloss:0.07697	validation_1-error:0.035755	validation_1-logloss:0.107143
# [219]	validation_0-error:0.014006	validation_0-logloss:0.076578	validation_1-error:0.035473	validation_1-logloss:0.106755
# [220]	validation_0-error:0.013795	validation_0-logloss:0.076253	validation_1-error:0.03491	validation_1-logloss:0.106437
# [221]	validation_0-error:0.013443	validation_0-logloss:0.075859	validation_1-error:0.03491	validation_1-logloss:0.10611
# [222]	validation_0-error:0.013162	validation_0-logloss:0.075498	validation_1-error:0.03491	validation_1-logloss:0.105665
# [223]	validation_0-error:0.013232	validation_0-logloss:0.07511	validation_1-error:0.03491	validation_1-logloss:0.105372
# [224]	validation_0-error:0.013302	validation_0-logloss:0.07465	validation_1-error:0.03491	validation_1-logloss:0.104853
# [225]	validation_0-error:0.013302	validation_0-logloss:0.07422	validation_1-error:0.034628	validation_1-logloss:0.104546
# [226]	validation_0-error:0.013232	validation_0-logloss:0.073748	validation_1-error:0.035191	validation_1-logloss:0.104219
# [227]	validation_0-error:0.013232	validation_0-logloss:0.073329	validation_1-error:0.03491	validation_1-logloss:0.103834
# [228]	validation_0-error:0.013302	validation_0-logloss:0.072907	validation_1-error:0.03491	validation_1-logloss:0.10361
# [229]	validation_0-error:0.013232	validation_0-logloss:0.072657	validation_1-error:0.034065	validation_1-logloss:0.10344
# [230]	validation_0-error:0.013232	validation_0-logloss:0.072335	validation_1-error:0.034347	validation_1-logloss:0.103147
# [231]	validation_0-error:0.013162	validation_0-logloss:0.072011	validation_1-error:0.03491	validation_1-logloss:0.102909
# [232]	validation_0-error:0.013302	validation_0-logloss:0.071678	validation_1-error:0.03491	validation_1-logloss:0.102603
# [233]	validation_0-error:0.01295	validation_0-logloss:0.071396	validation_1-error:0.034065	validation_1-logloss:0.102312
# [234]	validation_0-error:0.013091	validation_0-logloss:0.071024	validation_1-error:0.033784	validation_1-logloss:0.101971
# [235]	validation_0-error:0.01295	validation_0-logloss:0.070742	validation_1-error:0.033502	validation_1-logloss:0.101811
# [236]	validation_0-error:0.013021	validation_0-logloss:0.070434	validation_1-error:0.033784	validation_1-logloss:0.101635
# [237]	validation_0-error:0.012528	validation_0-logloss:0.070068	validation_1-error:0.034065	validation_1-logloss:0.101237
# [238]	validation_0-error:0.012387	validation_0-logloss:0.069697	validation_1-error:0.034347	validation_1-logloss:0.101007
# [239]	validation_0-error:0.012669	validation_0-logloss:0.069381	validation_1-error:0.034065	validation_1-logloss:0.100854
# [240]	validation_0-error:0.012176	validation_0-logloss:0.068958	validation_1-error:0.034347	validation_1-logloss:0.100403
# [241]	validation_0-error:0.011965	validation_0-logloss:0.068623	validation_1-error:0.034065	validation_1-logloss:0.100112
# [242]	validation_0-error:0.011895	validation_0-logloss:0.068267	validation_1-error:0.033784	validation_1-logloss:0.099759
# [243]	validation_0-error:0.011824	validation_0-logloss:0.067886	validation_1-error:0.033784	validation_1-logloss:0.099511
# [244]	validation_0-error:0.011824	validation_0-logloss:0.067602	validation_1-error:0.033784	validation_1-logloss:0.099282
# [245]	validation_0-error:0.011965	validation_0-logloss:0.067377	validation_1-error:0.033784	validation_1-logloss:0.099153
# [246]	validation_0-error:0.011472	validation_0-logloss:0.067023	validation_1-error:0.033502	validation_1-logloss:0.098596
# [247]	validation_0-error:0.011191	validation_0-logloss:0.066738	validation_1-error:0.033784	validation_1-logloss:0.098318
# [248]	validation_0-error:0.01112	validation_0-logloss:0.066404	validation_1-error:0.033784	validation_1-logloss:0.097981
# [249]	validation_0-error:0.01098	validation_0-logloss:0.066193	validation_1-error:0.033784	validation_1-logloss:0.097849
# [250]	validation_0-error:0.010839	validation_0-logloss:0.065828	validation_1-error:0.033221	validation_1-logloss:0.097567
# [251]	validation_0-error:0.010628	validation_0-logloss:0.065452	validation_1-error:0.033502	validation_1-logloss:0.09703
# [252]	validation_0-error:0.010769	validation_0-logloss:0.065098	validation_1-error:0.032939	validation_1-logloss:0.096716
# [253]	validation_0-error:0.010487	validation_0-logloss:0.064743	validation_1-error:0.033221	validation_1-logloss:0.096263
# [254]	validation_0-error:0.010487	validation_0-logloss:0.064363	validation_1-error:0.033221	validation_1-logloss:0.096006
# [255]	validation_0-error:0.010487	validation_0-logloss:0.063961	validation_1-error:0.031813	validation_1-logloss:0.095613
# [256]	validation_0-error:0.010276	validation_0-logloss:0.063634	validation_1-error:0.031813	validation_1-logloss:0.095226
# [257]	validation_0-error:0.010065	validation_0-logloss:0.063343	validation_1-error:0.032376	validation_1-logloss:0.095041
# [258]	validation_0-error:0.010135	validation_0-logloss:0.062994	validation_1-error:0.032658	validation_1-logloss:0.094653
# [259]	validation_0-error:0.009854	validation_0-logloss:0.062681	validation_1-error:0.032658	validation_1-logloss:0.094283
# [260]	validation_0-error:0.009994	validation_0-logloss:0.062371	validation_1-error:0.032658	validation_1-logloss:0.094239
# [261]	validation_0-error:0.009924	validation_0-logloss:0.062146	validation_1-error:0.032658	validation_1-logloss:0.094071
# [262]	validation_0-error:0.009572	validation_0-logloss:0.061833	validation_1-error:0.033784	validation_1-logloss:0.093946
# [263]	validation_0-error:0.009502	validation_0-logloss:0.061558	validation_1-error:0.033221	validation_1-logloss:0.093808
# [264]	validation_0-error:0.009642	validation_0-logloss:0.061234	validation_1-error:0.033221	validation_1-logloss:0.0935
# [265]	validation_0-error:0.009361	validation_0-logloss:0.060888	validation_1-error:0.032658	validation_1-logloss:0.093173
# [266]	validation_0-error:0.009502	validation_0-logloss:0.060493	validation_1-error:0.032376	validation_1-logloss:0.09294
# [267]	validation_0-error:0.009291	validation_0-logloss:0.060278	validation_1-error:0.032658	validation_1-logloss:0.092809
# [268]	validation_0-error:0.009502	validation_0-logloss:0.060002	validation_1-error:0.032095	validation_1-logloss:0.092558
# [269]	validation_0-error:0.00915	validation_0-logloss:0.0598	validation_1-error:0.032095	validation_1-logloss:0.092328
# [270]	validation_0-error:0.009361	validation_0-logloss:0.059506	validation_1-error:0.031813	validation_1-logloss:0.092
# [271]	validation_0-error:0.00915	validation_0-logloss:0.059246	validation_1-error:0.031813	validation_1-logloss:0.091897
# [272]	validation_0-error:0.00922	validation_0-logloss:0.058952	validation_1-error:0.032376	validation_1-logloss:0.091654
# [273]	validation_0-error:0.00922	validation_0-logloss:0.058736	validation_1-error:0.032658	validation_1-logloss:0.091445
# [274]	validation_0-error:0.008868	validation_0-logloss:0.058491	validation_1-error:0.032376	validation_1-logloss:0.091174
# [275]	validation_0-error:0.008939	validation_0-logloss:0.058275	validation_1-error:0.032658	validation_1-logloss:0.091002
# [276]	validation_0-error:0.008939	validation_0-logloss:0.057998	validation_1-error:0.032658	validation_1-logloss:0.090754
# [277]	validation_0-error:0.008868	validation_0-logloss:0.057687	validation_1-error:0.031813	validation_1-logloss:0.090464
# [278]	validation_0-error:0.009009	validation_0-logloss:0.05742	validation_1-error:0.032095	validation_1-logloss:0.090207
# [279]	validation_0-error:0.008868	validation_0-logloss:0.057182	validation_1-error:0.03125	validation_1-logloss:0.089966
# [280]	validation_0-error:0.008657	validation_0-logloss:0.056987	validation_1-error:0.030968	validation_1-logloss:0.08974
# [281]	validation_0-error:0.008446	validation_0-logloss:0.056755	validation_1-error:0.03125	validation_1-logloss:0.089633
# [282]	validation_0-error:0.008516	validation_0-logloss:0.056518	validation_1-error:0.030968	validation_1-logloss:0.089437
# [283]	validation_0-error:0.008516	validation_0-logloss:0.056281	validation_1-error:0.030968	validation_1-logloss:0.08927
# [284]	validation_0-error:0.008516	validation_0-logloss:0.056115	validation_1-error:0.030687	validation_1-logloss:0.089131
# [285]	validation_0-error:0.008235	validation_0-logloss:0.055863	validation_1-error:0.030405	validation_1-logloss:0.088874
# [286]	validation_0-error:0.008305	validation_0-logloss:0.055551	validation_1-error:0.029561	validation_1-logloss:0.088626
# [287]	validation_0-error:0.008305	validation_0-logloss:0.055232	validation_1-error:0.030124	validation_1-logloss:0.088487
# [288]	validation_0-error:0.008235	validation_0-logloss:0.054956	validation_1-error:0.030124	validation_1-logloss:0.088237
# [289]	validation_0-error:0.008164	validation_0-logloss:0.054692	validation_1-error:0.028716	validation_1-logloss:0.087922
# [290]	validation_0-error:0.008024	validation_0-logloss:0.054452	validation_1-error:0.029561	validation_1-logloss:0.087613
# [291]	validation_0-error:0.008024	validation_0-logloss:0.054162	validation_1-error:0.028716	validation_1-logloss:0.087464
# [292]	validation_0-error:0.007672	validation_0-logloss:0.053898	validation_1-error:0.028153	validation_1-logloss:0.087206
# [293]	validation_0-error:0.007742	validation_0-logloss:0.053667	validation_1-error:0.029561	validation_1-logloss:0.086982
# [294]	validation_0-error:0.007672	validation_0-logloss:0.053404	validation_1-error:0.029279	validation_1-logloss:0.086798
# [295]	validation_0-error:0.007883	validation_0-logloss:0.053149	validation_1-error:0.029842	validation_1-logloss:0.086687
# [296]	validation_0-error:0.007812	validation_0-logloss:0.052857	validation_1-error:0.029561	validation_1-logloss:0.086446
# [297]	validation_0-error:0.007883	validation_0-logloss:0.052609	validation_1-error:0.029561	validation_1-logloss:0.086173
# [298]	validation_0-error:0.007812	validation_0-logloss:0.05244	validation_1-error:0.029561	validation_1-logloss:0.085974
# [299]	validation_0-error:0.007601	validation_0-logloss:0.052223	validation_1-error:0.029279	validation_1-logloss:0.085885
# [300]	validation_0-error:0.007672	validation_0-logloss:0.05195	validation_1-error:0.029279	validation_1-logloss:0.085587
# [301]	validation_0-error:0.007531	validation_0-logloss:0.051739	validation_1-error:0.028998	validation_1-logloss:0.085496
# [302]	validation_0-error:0.007531	validation_0-logloss:0.051445	validation_1-error:0.029561	validation_1-logloss:0.0852
# [303]	validation_0-error:0.00739	validation_0-logloss:0.051237	validation_1-error:0.029842	validation_1-logloss:0.084945
# [304]	validation_0-error:0.00739	validation_0-logloss:0.051042	validation_1-error:0.029561	validation_1-logloss:0.084732
# [305]	validation_0-error:0.007461	validation_0-logloss:0.050843	validation_1-error:0.029561	validation_1-logloss:0.084564
# [306]	validation_0-error:0.007601	validation_0-logloss:0.050597	validation_1-error:0.028435	validation_1-logloss:0.084366
# [307]	validation_0-error:0.00732	validation_0-logloss:0.050399	validation_1-error:0.028435	validation_1-logloss:0.08415
# [308]	validation_0-error:0.007179	validation_0-logloss:0.05015	validation_1-error:0.028435	validation_1-logloss:0.083941
# [309]	validation_0-error:0.007179	validation_0-logloss:0.049862	validation_1-error:0.028153	validation_1-logloss:0.083582
# [310]	validation_0-error:0.006898	validation_0-logloss:0.049572	validation_1-error:0.028435	validation_1-logloss:0.083277
# [311]	validation_0-error:0.006968	validation_0-logloss:0.04937	validation_1-error:0.028153	validation_1-logloss:0.083127
# [312]	validation_0-error:0.006757	validation_0-logloss:0.049096	validation_1-error:0.028153	validation_1-logloss:0.082899
# [313]	validation_0-error:0.006686	validation_0-logloss:0.048869	validation_1-error:0.027872	validation_1-logloss:0.082645
# [314]	validation_0-error:0.006616	validation_0-logloss:0.048626	validation_1-error:0.027309	validation_1-logloss:0.082324
# [315]	validation_0-error:0.006475	validation_0-logloss:0.04837	validation_1-error:0.02759	validation_1-logloss:0.082098
# [316]	validation_0-error:0.006405	validation_0-logloss:0.048175	validation_1-error:0.027309	validation_1-logloss:0.08187
# [317]	validation_0-error:0.006616	validation_0-logloss:0.047919	validation_1-error:0.027027	validation_1-logloss:0.0816
# [318]	validation_0-error:0.006334	validation_0-logloss:0.047663	validation_1-error:0.026745	validation_1-logloss:0.081321
# [319]	validation_0-error:0.006405	validation_0-logloss:0.04752	validation_1-error:0.027027	validation_1-logloss:0.081211
# [320]	validation_0-error:0.006405	validation_0-logloss:0.047263	validation_1-error:0.026745	validation_1-logloss:0.081014
# [321]	validation_0-error:0.006546	validation_0-logloss:0.047064	validation_1-error:0.027027	validation_1-logloss:0.080818
# [322]	validation_0-error:0.006194	validation_0-logloss:0.046848	validation_1-error:0.027027	validation_1-logloss:0.080717
# [323]	validation_0-error:0.006264	validation_0-logloss:0.046603	validation_1-error:0.027027	validation_1-logloss:0.08047
# [324]	validation_0-error:0.006264	validation_0-logloss:0.046465	validation_1-error:0.027309	validation_1-logloss:0.080361
# [325]	validation_0-error:0.006264	validation_0-logloss:0.046249	validation_1-error:0.026745	validation_1-logloss:0.080143
# [326]	validation_0-error:0.006194	validation_0-logloss:0.046052	validation_1-error:0.027027	validation_1-logloss:0.079966
# [327]	validation_0-error:0.006194	validation_0-logloss:0.045797	validation_1-error:0.026464	validation_1-logloss:0.079721
# [328]	validation_0-error:0.005983	validation_0-logloss:0.045593	validation_1-error:0.026464	validation_1-logloss:0.079537
# [329]	validation_0-error:0.005912	validation_0-logloss:0.045385	validation_1-error:0.027027	validation_1-logloss:0.079359
# [330]	validation_0-error:0.005842	validation_0-logloss:0.045153	validation_1-error:0.026745	validation_1-logloss:0.079171
# [331]	validation_0-error:0.005631	validation_0-logloss:0.044881	validation_1-error:0.026182	validation_1-logloss:0.078898
# [332]	validation_0-error:0.00556	validation_0-logloss:0.04465	validation_1-error:0.025901	validation_1-logloss:0.078621
# [333]	validation_0-error:0.005631	validation_0-logloss:0.044437	validation_1-error:0.026464	validation_1-logloss:0.078433
# [334]	validation_0-error:0.005419	validation_0-logloss:0.044241	validation_1-error:0.026182	validation_1-logloss:0.078277
# [335]	validation_0-error:0.005419	validation_0-logloss:0.044033	validation_1-error:0.025901	validation_1-logloss:0.078082
# [336]	validation_0-error:0.00549	validation_0-logloss:0.043784	validation_1-error:0.025901	validation_1-logloss:0.077839
# [337]	validation_0-error:0.00549	validation_0-logloss:0.043589	validation_1-error:0.025901	validation_1-logloss:0.077668
# [338]	validation_0-error:0.005419	validation_0-logloss:0.043399	validation_1-error:0.025619	validation_1-logloss:0.077514
# [339]	validation_0-error:0.005279	validation_0-logloss:0.043187	validation_1-error:0.025901	validation_1-logloss:0.077276
# [340]	validation_0-error:0.005419	validation_0-logloss:0.042977	validation_1-error:0.025619	validation_1-logloss:0.077103
# [341]	validation_0-error:0.005349	validation_0-logloss:0.042804	validation_1-error:0.025338	validation_1-logloss:0.076893
# [342]	validation_0-error:0.005349	validation_0-logloss:0.042699	validation_1-error:0.025338	validation_1-logloss:0.076814
# [343]	validation_0-error:0.005279	validation_0-logloss:0.042536	validation_1-error:0.025338	validation_1-logloss:0.076694
# [344]	validation_0-error:0.005349	validation_0-logloss:0.042393	validation_1-error:0.024775	validation_1-logloss:0.076518
# [345]	validation_0-error:0.005279	validation_0-logloss:0.042212	validation_1-error:0.025056	validation_1-logloss:0.076271
# [346]	validation_0-error:0.005208	validation_0-logloss:0.04203	validation_1-error:0.025338	validation_1-logloss:0.075986
# [347]	validation_0-error:0.005279	validation_0-logloss:0.041842	validation_1-error:0.025619	validation_1-logloss:0.07584
# [348]	validation_0-error:0.005138	validation_0-logloss:0.041639	validation_1-error:0.025056	validation_1-logloss:0.075603
# [349]	validation_0-error:0.005068	validation_0-logloss:0.041447	validation_1-error:0.025056	validation_1-logloss:0.075449
# [350]	validation_0-error:0.004997	validation_0-logloss:0.041247	validation_1-error:0.025338	validation_1-logloss:0.075313
# [351]	validation_0-error:0.004997	validation_0-logloss:0.041057	validation_1-error:0.025056	validation_1-logloss:0.075137
# [352]	validation_0-error:0.004927	validation_0-logloss:0.040877	validation_1-error:0.025056	validation_1-logloss:0.074953
# [353]	validation_0-error:0.004997	validation_0-logloss:0.040771	validation_1-error:0.024775	validation_1-logloss:0.074934
# [354]	validation_0-error:0.004786	validation_0-logloss:0.040553	validation_1-error:0.024493	validation_1-logloss:0.074796
# [355]	validation_0-error:0.004856	validation_0-logloss:0.040399	validation_1-error:0.024493	validation_1-logloss:0.074607
# [356]	validation_0-error:0.004927	validation_0-logloss:0.040232	validation_1-error:0.024212	validation_1-logloss:0.074467
# [357]	validation_0-error:0.004786	validation_0-logloss:0.040023	validation_1-error:0.02393	validation_1-logloss:0.074264
# [358]	validation_0-error:0.004786	validation_0-logloss:0.039877	validation_1-error:0.024212	validation_1-logloss:0.074111
# [359]	validation_0-error:0.004645	validation_0-logloss:0.039762	validation_1-error:0.02393	validation_1-logloss:0.074005
# [360]	validation_0-error:0.004786	validation_0-logloss:0.03957	validation_1-error:0.023649	validation_1-logloss:0.073757
# [361]	validation_0-error:0.004716	validation_0-logloss:0.039395	validation_1-error:0.02393	validation_1-logloss:0.073562
# [362]	validation_0-error:0.004645	validation_0-logloss:0.039283	validation_1-error:0.023367	validation_1-logloss:0.073459
# [363]	validation_0-error:0.004575	validation_0-logloss:0.039129	validation_1-error:0.023367	validation_1-logloss:0.073416
# [364]	validation_0-error:0.004434	validation_0-logloss:0.038953	validation_1-error:0.023367	validation_1-logloss:0.073278
# [365]	validation_0-error:0.004364	validation_0-logloss:0.038744	validation_1-error:0.023649	validation_1-logloss:0.07309
# [366]	validation_0-error:0.004364	validation_0-logloss:0.038597	validation_1-error:0.023367	validation_1-logloss:0.072878
# [367]	validation_0-error:0.004293	validation_0-logloss:0.038462	validation_1-error:0.023649	validation_1-logloss:0.072747
# [368]	validation_0-error:0.004293	validation_0-logloss:0.038262	validation_1-error:0.023649	validation_1-logloss:0.0725
# [369]	validation_0-error:0.004364	validation_0-logloss:0.038118	validation_1-error:0.023367	validation_1-logloss:0.072406
# [370]	validation_0-error:0.004293	validation_0-logloss:0.037944	validation_1-error:0.023649	validation_1-logloss:0.072305
# [371]	validation_0-error:0.004364	validation_0-logloss:0.037769	validation_1-error:0.023367	validation_1-logloss:0.072227
# [372]	validation_0-error:0.004364	validation_0-logloss:0.03766	validation_1-error:0.023367	validation_1-logloss:0.072171
# [373]	validation_0-error:0.004293	validation_0-logloss:0.037536	validation_1-error:0.023367	validation_1-logloss:0.072017
# [374]	validation_0-error:0.004434	validation_0-logloss:0.037351	validation_1-error:0.023367	validation_1-logloss:0.071903
# [375]	validation_0-error:0.004293	validation_0-logloss:0.037207	validation_1-error:0.023086	validation_1-logloss:0.071777
# [376]	validation_0-error:0.004293	validation_0-logloss:0.037063	validation_1-error:0.023086	validation_1-logloss:0.071601
# [377]	validation_0-error:0.004293	validation_0-logloss:0.03692	validation_1-error:0.022804	validation_1-logloss:0.07145
# [378]	validation_0-error:0.004223	validation_0-logloss:0.036775	validation_1-error:0.022804	validation_1-logloss:0.071337
# [379]	validation_0-error:0.004293	validation_0-logloss:0.03658	validation_1-error:0.022804	validation_1-logloss:0.071142
# [380]	validation_0-error:0.004223	validation_0-logloss:0.036481	validation_1-error:0.022804	validation_1-logloss:0.071048
# [381]	validation_0-error:0.004223	validation_0-logloss:0.036298	validation_1-error:0.023086	validation_1-logloss:0.070914
# [382]	validation_0-error:0.004223	validation_0-logloss:0.036185	validation_1-error:0.023086	validation_1-logloss:0.07093
# [383]	validation_0-error:0.004293	validation_0-logloss:0.036013	validation_1-error:0.023086	validation_1-logloss:0.070791
# [384]	validation_0-error:0.004082	validation_0-logloss:0.035836	validation_1-error:0.022804	validation_1-logloss:0.070597
# [385]	validation_0-error:0.004012	validation_0-logloss:0.035704	validation_1-error:0.022804	validation_1-logloss:0.070446
# [386]	validation_0-error:0.004012	validation_0-logloss:0.035544	validation_1-error:0.022804	validation_1-logloss:0.070274
# [387]	validation_0-error:0.004082	validation_0-logloss:0.035396	validation_1-error:0.022804	validation_1-logloss:0.0702
# [388]	validation_0-error:0.004012	validation_0-logloss:0.035281	validation_1-error:0.022804	validation_1-logloss:0.070118
# [389]	validation_0-error:0.004082	validation_0-logloss:0.035111	validation_1-error:0.023086	validation_1-logloss:0.070087
# [390]	validation_0-error:0.003941	validation_0-logloss:0.034932	validation_1-error:0.023367	validation_1-logloss:0.069875
# [391]	validation_0-error:0.003871	validation_0-logloss:0.034777	validation_1-error:0.023367	validation_1-logloss:0.06972
# [392]	validation_0-error:0.003801	validation_0-logloss:0.034608	validation_1-error:0.023367	validation_1-logloss:0.069561
# [393]	validation_0-error:0.003871	validation_0-logloss:0.03446	validation_1-error:0.023649	validation_1-logloss:0.069527
# [394]	validation_0-error:0.003871	validation_0-logloss:0.034301	validation_1-error:0.023649	validation_1-logloss:0.069352
# ...
# [864]	validation_0-error:0	validation_0-logloss:0.006114	validation_1-error:0.014921	validation_1-logloss:0.042224
# [865]	validation_0-error:0	validation_0-logloss:0.006091	validation_1-error:0.014921	validation_1-logloss:0.042225
# [866]	validation_0-error:0	validation_0-logloss:0.006064	validation_1-error:0.014921	validation_1-logloss:0.042175
# [867]	validation_0-error:0	validation_0-logloss:0.006047	validation_1-error:0.014921	validation_1-logloss:0.0421
# [868]	validation_0-error:0	validation_0-logloss:0.006025	validation_1-error:0.014921	validation_1-logloss:0.042009
# [869]	validation_0-error:0	validation_0-logloss:0.006004	validation_1-error:0.015203	validation_1-logloss:0.042005
# [870]	validation_0-error:0	validation_0-logloss:0.005986	validation_1-error:0.015203	validation_1-logloss:0.041981
# [871]	validation_0-error:0	validation_0-logloss:0.005968	validation_1-error:0.015203	validation_1-logloss:0.041957
# [872]	validation_0-error:0	validation_0-logloss:0.00595	validation_1-error:0.015203	validation_1-logloss:0.041951
# [873]	validation_0-error:0	validation_0-logloss:0.005927	validation_1-error:0.015203	validation_1-logloss:0.041976
# [874]	validation_0-error:0	validation_0-logloss:0.005908	validation_1-error:0.015203	validation_1-logloss:0.041931
# [875]	validation_0-error:0	validation_0-logloss:0.005897	validation_1-error:0.015203	validation_1-logloss:0.041912
# [876]	validation_0-error:0	validation_0-logloss:0.005877	validation_1-error:0.015203	validation_1-logloss:0.041864
# [877]	validation_0-error:0	validation_0-logloss:0.005857	validation_1-error:0.015203	validation_1-logloss:0.041825
# [878]	validation_0-error:0	validation_0-logloss:0.005838	validation_1-error:0.015484	validation_1-logloss:0.041755
# [879]	validation_0-error:0	validation_0-logloss:0.005821	validation_1-error:0.015484	validation_1-logloss:0.041733
# [880]	validation_0-error:0	validation_0-logloss:0.005802	validation_1-error:0.015484	validation_1-logloss:0.041739
# [881]	validation_0-error:0	validation_0-logloss:0.005785	validation_1-error:0.015484	validation_1-logloss:0.041769
# [882]	validation_0-error:0	validation_0-logloss:0.005766	validation_1-error:0.015484	validation_1-logloss:0.041749
# [883]	validation_0-error:0	validation_0-logloss:0.005745	validation_1-error:0.015203	validation_1-logloss:0.041737
# [884]	validation_0-error:0	validation_0-logloss:0.005723	validation_1-error:0.015203	validation_1-logloss:0.041674
# [885]	validation_0-error:0	validation_0-logloss:0.005706	validation_1-error:0.015203	validation_1-logloss:0.041672
# [886]	validation_0-error:0	validation_0-logloss:0.005687	validation_1-error:0.015203	validation_1-logloss:0.041645
# [887]	validation_0-error:0	validation_0-logloss:0.005673	validation_1-error:0.015484	validation_1-logloss:0.041685
# [888]	validation_0-error:0	validation_0-logloss:0.005657	validation_1-error:0.015484	validation_1-logloss:0.041627
# [889]	validation_0-error:0	validation_0-logloss:0.005639	validation_1-error:0.015484	validation_1-logloss:0.041534
# [890]	validation_0-error:0	validation_0-logloss:0.00562	validation_1-error:0.015484	validation_1-logloss:0.041545
# [891]	validation_0-error:0	validation_0-logloss:0.005594	validation_1-error:0.015484	validation_1-logloss:0.041496
# [892]	validation_0-error:0	validation_0-logloss:0.005576	validation_1-error:0.015484	validation_1-logloss:0.041477
# [893]	validation_0-error:0	validation_0-logloss:0.005563	validation_1-error:0.015484	validation_1-logloss:0.041433
# [894]	validation_0-error:0	validation_0-logloss:0.005544	validation_1-error:0.015484	validation_1-logloss:0.041407
# [895]	validation_0-error:0	validation_0-logloss:0.005524	validation_1-error:0.015484	validation_1-logloss:0.041418
# [896]	validation_0-error:0	validation_0-logloss:0.005508	validation_1-error:0.015484	validation_1-logloss:0.041433
# [897]	validation_0-error:0	validation_0-logloss:0.005492	validation_1-error:0.015484	validation_1-logloss:0.041438
# [898]	validation_0-error:0	validation_0-logloss:0.005477	validation_1-error:0.015484	validation_1-logloss:0.041424
# [899]	validation_0-error:0	validation_0-logloss:0.005464	validation_1-error:0.015484	validation_1-logloss:0.04137
# [900]	validation_0-error:0	validation_0-logloss:0.005448	validation_1-error:0.015484	validation_1-logloss:0.041357
# [901]	validation_0-error:0	validation_0-logloss:0.005434	validation_1-error:0.015484	validation_1-logloss:0.04133
# [902]	validation_0-error:0	validation_0-logloss:0.005415	validation_1-error:0.015203	validation_1-logloss:0.041327
# [903]	validation_0-error:0	validation_0-logloss:0.005403	validation_1-error:0.015203	validation_1-logloss:0.041332
# [904]	validation_0-error:0	validation_0-logloss:0.005385	validation_1-error:0.015203	validation_1-logloss:0.041226
# [905]	validation_0-error:0	validation_0-logloss:0.005366	validation_1-error:0.015203	validation_1-logloss:0.041197
# [906]	validation_0-error:0	validation_0-logloss:0.005344	validation_1-error:0.015484	validation_1-logloss:0.041192
# [907]	validation_0-error:0	validation_0-logloss:0.005327	validation_1-error:0.015484	validation_1-logloss:0.04109
# [908]	validation_0-error:0	validation_0-logloss:0.005312	validation_1-error:0.015766	validation_1-logloss:0.041052
# [909]	validation_0-error:0	validation_0-logloss:0.005295	validation_1-error:0.015484	validation_1-logloss:0.041048
# [910]	validation_0-error:0	validation_0-logloss:0.00528	validation_1-error:0.015203	validation_1-logloss:0.04104
# [911]	validation_0-error:0	validation_0-logloss:0.005262	validation_1-error:0.014921	validation_1-logloss:0.04103
# [912]	validation_0-error:0	validation_0-logloss:0.00525	validation_1-error:0.015203	validation_1-logloss:0.041083
# [913]	validation_0-error:0	validation_0-logloss:0.00523	validation_1-error:0.014921	validation_1-logloss:0.041072
# [914]	validation_0-error:0	validation_0-logloss:0.005214	validation_1-error:0.015203	validation_1-logloss:0.041094
# [915]	validation_0-error:0	validation_0-logloss:0.0052	validation_1-error:0.015484	validation_1-logloss:0.041099
# [916]	validation_0-error:0	validation_0-logloss:0.005181	validation_1-error:0.015766	validation_1-logloss:0.041138
# [917]	validation_0-error:0	validation_0-logloss:0.005166	validation_1-error:0.015766	validation_1-logloss:0.041096
# [918]	validation_0-error:0	validation_0-logloss:0.005152	validation_1-error:0.015766	validation_1-logloss:0.041101
# [919]	validation_0-error:0	validation_0-logloss:0.005132	validation_1-error:0.015484	validation_1-logloss:0.041083
# [920]	validation_0-error:0	validation_0-logloss:0.005113	validation_1-error:0.015766	validation_1-logloss:0.041032
# [921]	validation_0-error:0	validation_0-logloss:0.005094	validation_1-error:0.015484	validation_1-logloss:0.041065
# [922]	validation_0-error:0	validation_0-logloss:0.005075	validation_1-error:0.015766	validation_1-logloss:0.041039
# [923]	validation_0-error:0	validation_0-logloss:0.005062	validation_1-error:0.015484	validation_1-logloss:0.041005
# [924]	validation_0-error:0	validation_0-logloss:0.005048	validation_1-error:0.015766	validation_1-logloss:0.040962
# [925]	validation_0-error:0	validation_0-logloss:0.005031	validation_1-error:0.015203	validation_1-logloss:0.040991
# [926]	validation_0-error:0	validation_0-logloss:0.005012	validation_1-error:0.015203	validation_1-logloss:0.040977
# [927]	validation_0-error:0	validation_0-logloss:0.005	validation_1-error:0.015203	validation_1-logloss:0.040967
# [928]	validation_0-error:0	validation_0-logloss:0.004983	validation_1-error:0.015766	validation_1-logloss:0.041002
# [929]	validation_0-error:0	validation_0-logloss:0.004966	validation_1-error:0.015484	validation_1-logloss:0.041017
# [930]	validation_0-error:0	validation_0-logloss:0.004954	validation_1-error:0.015203	validation_1-logloss:0.041031
# [931]	validation_0-error:0	validation_0-logloss:0.004937	validation_1-error:0.015766	validation_1-logloss:0.041064
# [932]	validation_0-error:0	validation_0-logloss:0.004926	validation_1-error:0.015766	validation_1-logloss:0.04101
# [933]	validation_0-error:0	validation_0-logloss:0.004908	validation_1-error:0.015766	validation_1-logloss:0.04092
# [934]	validation_0-error:0	validation_0-logloss:0.004889	validation_1-error:0.015766	validation_1-logloss:0.040951
# [935]	validation_0-error:0	validation_0-logloss:0.004872	validation_1-error:0.015766	validation_1-logloss:0.040991
# [936]	validation_0-error:0	validation_0-logloss:0.004853	validation_1-error:0.015484	validation_1-logloss:0.040955
# [937]	validation_0-error:0	validation_0-logloss:0.00484	validation_1-error:0.015484	validation_1-logloss:0.040934
# [938]	validation_0-error:0	validation_0-logloss:0.004827	validation_1-error:0.015766	validation_1-logloss:0.04097
# [939]	validation_0-error:0	validation_0-logloss:0.004814	validation_1-error:0.015484	validation_1-logloss:0.040936
# [940]	validation_0-error:0	validation_0-logloss:0.004801	validation_1-error:0.015484	validation_1-logloss:0.040906
# [941]	validation_0-error:0	validation_0-logloss:0.004791	validation_1-error:0.015203	validation_1-logloss:0.040896
# [942]	validation_0-error:0	validation_0-logloss:0.00478	validation_1-error:0.014921	validation_1-logloss:0.040877
# [943]	validation_0-error:0	validation_0-logloss:0.004763	validation_1-error:0.014921	validation_1-logloss:0.040826
# [944]	validation_0-error:0	validation_0-logloss:0.004751	validation_1-error:0.014921	validation_1-logloss:0.040782
# [945]	validation_0-error:0	validation_0-logloss:0.004738	validation_1-error:0.014921	validation_1-logloss:0.040767
# [946]	validation_0-error:0	validation_0-logloss:0.004729	validation_1-error:0.014921	validation_1-logloss:0.040677
# [947]	validation_0-error:0	validation_0-logloss:0.004715	validation_1-error:0.014921	validation_1-logloss:0.04065
# [948]	validation_0-error:0	validation_0-logloss:0.0047	validation_1-error:0.014921	validation_1-logloss:0.040598
# [949]	validation_0-error:0	validation_0-logloss:0.004687	validation_1-error:0.01464	validation_1-logloss:0.040567
# [950]	validation_0-error:0	validation_0-logloss:0.004675	validation_1-error:0.014921	validation_1-logloss:0.040596
# [951]	validation_0-error:0	validation_0-logloss:0.004665	validation_1-error:0.01464	validation_1-logloss:0.040574
# [952]	validation_0-error:0	validation_0-logloss:0.004648	validation_1-error:0.014921	validation_1-logloss:0.040577
# [953]	validation_0-error:0	validation_0-logloss:0.004637	validation_1-error:0.014921	validation_1-logloss:0.040568
# [954]	validation_0-error:0	validation_0-logloss:0.004619	validation_1-error:0.015203	validation_1-logloss:0.04055
# [955]	validation_0-error:0	validation_0-logloss:0.00461	validation_1-error:0.015203	validation_1-logloss:0.040583
# [956]	validation_0-error:0	validation_0-logloss:0.004598	validation_1-error:0.015203	validation_1-logloss:0.040562
# [957]	validation_0-error:0	validation_0-logloss:0.004585	validation_1-error:0.015203	validation_1-logloss:0.040527
# [958]	validation_0-error:0	validation_0-logloss:0.004571	validation_1-error:0.015203	validation_1-logloss:0.040511
# [959]	validation_0-error:0	validation_0-logloss:0.004559	validation_1-error:0.015203	validation_1-logloss:0.040481
# [960]	validation_0-error:0	validation_0-logloss:0.00455	validation_1-error:0.015203	validation_1-logloss:0.040477
# [961]	validation_0-error:0	validation_0-logloss:0.004532	validation_1-error:0.014921	validation_1-logloss:0.040388
# [962]	validation_0-error:0	validation_0-logloss:0.004522	validation_1-error:0.014921	validation_1-logloss:0.040334
# [963]	validation_0-error:0	validation_0-logloss:0.004508	validation_1-error:0.015203	validation_1-logloss:0.040312
# [964]	validation_0-error:0	validation_0-logloss:0.004494	validation_1-error:0.015203	validation_1-logloss:0.040279
# [965]	validation_0-error:0	validation_0-logloss:0.004482	validation_1-error:0.015203	validation_1-logloss:0.040207
# [966]	validation_0-error:0	validation_0-logloss:0.004465	validation_1-error:0.01464	validation_1-logloss:0.040167
# [967]	validation_0-error:0	validation_0-logloss:0.004453	validation_1-error:0.015203	validation_1-logloss:0.040152
# [968]	validation_0-error:0	validation_0-logloss:0.004438	validation_1-error:0.015203	validation_1-logloss:0.040171
# [969]	validation_0-error:0	validation_0-logloss:0.004427	validation_1-error:0.014921	validation_1-logloss:0.040134
# [970]	validation_0-error:0	validation_0-logloss:0.004413	validation_1-error:0.015203	validation_1-logloss:0.040144
# [971]	validation_0-error:0	validation_0-logloss:0.0044	validation_1-error:0.014921	validation_1-logloss:0.040139
# [972]	validation_0-error:0	validation_0-logloss:0.004388	validation_1-error:0.014921	validation_1-logloss:0.040131
# [973]	validation_0-error:0	validation_0-logloss:0.004374	validation_1-error:0.014921	validation_1-logloss:0.040118
# [974]	validation_0-error:0	validation_0-logloss:0.004361	validation_1-error:0.014921	validation_1-logloss:0.040109
# [975]	validation_0-error:0	validation_0-logloss:0.00435	validation_1-error:0.014921	validation_1-logloss:0.040152
# [976]	validation_0-error:0	validation_0-logloss:0.004337	validation_1-error:0.014921	validation_1-logloss:0.040141
# [977]	validation_0-error:0	validation_0-logloss:0.004326	validation_1-error:0.01464	validation_1-logloss:0.040121
# [978]	validation_0-error:0	validation_0-logloss:0.004312	validation_1-error:0.01464	validation_1-logloss:0.040082
# [979]	validation_0-error:0	validation_0-logloss:0.004301	validation_1-error:0.014921	validation_1-logloss:0.040083
# [980]	validation_0-error:0	validation_0-logloss:0.004287	validation_1-error:0.01464	validation_1-logloss:0.04003
# [981]	validation_0-error:0	validation_0-logloss:0.004272	validation_1-error:0.01464	validation_1-logloss:0.039983
# [982]	validation_0-error:0	validation_0-logloss:0.004259	validation_1-error:0.01464	validation_1-logloss:0.040027
# [983]	validation_0-error:0	validation_0-logloss:0.004246	validation_1-error:0.01464	validation_1-logloss:0.040052
# [984]	validation_0-error:0	validation_0-logloss:0.004237	validation_1-error:0.01464	validation_1-logloss:0.040061
# [985]	validation_0-error:0	validation_0-logloss:0.004224	validation_1-error:0.01464	validation_1-logloss:0.040046
# [986]	validation_0-error:0	validation_0-logloss:0.004212	validation_1-error:0.014358	validation_1-logloss:0.040026
# [987]	validation_0-error:0	validation_0-logloss:0.004203	validation_1-error:0.014358	validation_1-logloss:0.04006
# [988]	validation_0-error:0	validation_0-logloss:0.004195	validation_1-error:0.014358	validation_1-logloss:0.040103
# [989]	validation_0-error:0	validation_0-logloss:0.004187	validation_1-error:0.014358	validation_1-logloss:0.040115
# [990]	validation_0-error:0	validation_0-logloss:0.004174	validation_1-error:0.014358	validation_1-logloss:0.040088
# [991]	validation_0-error:0	validation_0-logloss:0.004158	validation_1-error:0.014358	validation_1-logloss:0.040056
# [992]	validation_0-error:0	validation_0-logloss:0.004147	validation_1-error:0.014358	validation_1-logloss:0.04009
# [993]	validation_0-error:0	validation_0-logloss:0.004134	validation_1-error:0.01464	validation_1-logloss:0.040125
# [994]	validation_0-error:0	validation_0-logloss:0.004121	validation_1-error:0.014921	validation_1-logloss:0.040089
# [995]	validation_0-error:0	validation_0-logloss:0.004113	validation_1-error:0.014358	validation_1-logloss:0.040089
# [996]	validation_0-error:0	validation_0-logloss:0.004096	validation_1-error:0.01464	validation_1-logloss:0.040065
# [997]	validation_0-error:0	validation_0-logloss:0.004085	validation_1-error:0.014358	validation_1-logloss:0.040031
# [998]	validation_0-error:0	validation_0-logloss:0.004078	validation_1-error:0.014358	validation_1-logloss:0.039988
# [999]	validation_0-error:0	validation_0-logloss:0.004066	validation_1-error:0.01464	validation_1-logloss:0.039966
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.5, gamma=0, learning_rate=0.05, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#        n_jobs=1, nthread=12, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=0.5)

# %%
# make predictions for test data
y_pred = model2.predict(X_test)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
plot_model_learning_curve(model2)
# Out:
# /home/xnguyen/.local/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy: 98.54%

# %%
# save model to file
pickle.dump((model2, X_scaler), open("xgboost_classifier.pkl", "wb"))

# %%
# load model from file
loaded_model, X_scaler = pickle.load(open("xgboost_classifier.pkl", "rb"))

# %%
# make predictions for test data
y_pred = loaded_model.predict(X_test)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
plot_model_learning_curve(model2)
# Out:
# /home/xnguyen/.local/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy: 98.54%

# %%
X_scaler
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
